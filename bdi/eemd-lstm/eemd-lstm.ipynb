# %% [markdown]
# <h2>Baltic Dry Index Prediction based on EEMD-LSTM</h2>

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import time
import os
import concurrent.futures
import scipy.signal as signal
from scipy.stats import norm
from scipy import interpolate
from datetime import datetime
from bs4 import BeautifulSoup
from urllib.request import urlopen
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l1, l2

# %% [markdown]
# <h3>1.1 資料收集</h3>
#
#     使用爬蟲獲取鉅亨網2000年至今波羅的海運價指數。

# %%
def scrapy(date):
    baseurl = 'https://www.cnyes.com/futures/History.aspx?mydate='
    his = date+'&code=BDI'
    url = baseurl + his
    try:
        respone = urlopen(url)
    except:
        pass
    else:
        html = urlopen(url).read().decode('utf-8')
        soup = BeautifulSoup(html)
        td = soup.find_all('td')
        if len(td)<21:
            return date
        else:
            return f'{date},{td[19].get_text()}'
        
def dateindex(start, end):
    return [datetime.strftime(i,'%Y%m%d') for i in list(pd.date_range(start=start, end=end))]

# %% [markdown]
# <h3>1.2 缺值</h3>
#
#     為確保每筆資料間隔時間固定，對缺值進行差值。

# %%
df = pd.read_csv('bdi.csv', parse_dates=['date'], index_col=['date'])
df.head()
# Out:
#                bdi
# date
# 2000-01-01  1319.0
# 2000-01-02     NaN
# 2000-01-03     NaN
# 2000-01-04  1320.0
# 2000-01-05  1329.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7588 entries, 2000-01-01 to 2020-10-09
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   bdi     5182 non-null   float64
# dtypes: float64(1)
# memory usage: 118.6 KB

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1,2,1)
plt.plot(df)
plt.subplot(1,2,2)
sb.heatmap(df.isnull(), yticklabels=False, cbar=True)
plt.figure(figsize=(16, 4))
sb.distplot(df, kde=True, fit=norm)
plt.show()

# %%
df = df.fillna(method='ffill')
plt.figure(figsize=(16, 4))
plt.subplot(1,2,1)
plt.plot(df)
plt.subplot(1,2,2)
sb.heatmap(df.isnull(), yticklabels=False, cbar=True)
plt.figure(figsize=(16, 4))
sb.distplot(df, kde=True, fit=norm)
plt.show()

# %%
data = df['bdi'].values
d = {'Actual': data}

# %% [markdown]
# <h3>2.1 總體經驗模態分解</h3>
#
#     經驗模態分解:
#     步驟一、判斷資料是否符合單調函數定義。
#             單調函數定義：無區域極值。
#     步驟二、判斷資料是否符合本徵模函數定義。
#             本徵模函數定義：零均值、區域極值總數與過零點總數相差小於等於1。
#     步驟三、利用資料的區域最大值與區域最小值，建立上包絡線與下包絡線。
#     步驟四、資料減去上下包絡線的平均。
#     步驟五、判斷資料是否符合本徵模函數定義。如未符合重複步驟三四。符合則產生第一組模態。
#     步驟六、資料減去第一組模態，判斷是否符合單調函數，如未符合重複步驟三四五。
#     步驟七、資料完成分解為多組本徵模函數，與一組單調函數。
#
#     弊病：
#     邊界效應、位於邊界的包絡線因差值困難導致失真。
#     模態數量不一致、資料長度的增減會導致模態的數量產生變化。
#     混模、小範圍噪音會影響模態分解的品質，並持續傳播影響後面多組模態。
#
#     解決方法：
#     鏡像擴充
#     總體經驗模態分解

# %%
def ismonotonic(x):
    max_peaks = signal.argrelextrema(x, np.greater)[0]
    min_peaks = signal.argrelextrema(x, np.less)[0]
    all_num = len(max_peaks) + len(min_peaks)
    if all_num > 0:
        return False
    else:
        return True

def isimf(x):
    N = np.size(x)
    pass_zero = np.sum(x[0:N - 2] * x[1:N - 1] < 0)
    peaks_num = np.size(findpeaks(x)) + np.size(findpeaks(-x))
    if abs(pass_zero - peaks_num) > 1:
        return False
    else:
        return True

def findpeaks(x):
    return signal.argrelextrema(x, np.greater)[0]

def getspline(x):
    N = np.size(x)
    peaks = findpeaks(x)
    if len(peaks) <= 3:
        if len(peaks) < 2:
            peaks = np.concatenate(([0], peaks))
            peaks = np.concatenate((peaks, [N - 1]))
        t = interpolate.splrep(peaks, y=x[peaks], w=None, xb=None, xe=None, k=len(peaks) - 1)
        return interpolate.splev(np.arange(N), t)
    t = interpolate.splrep(peaks, y=x[peaks])
    return interpolate.splev(np.arange(N), t)

def noise(x, amp):
    return x + (np.random.randn(len(x)) * amp)

def mirror(x):
    i = np.arange(len(x) - 2, 0, -1)
    reverse_x = x[i]
    reverse_x = list(reverse_x)
    x = list(x)
    return np.array(reverse_x + x + reverse_x)

def emd(x):
    imf = []
    while not ismonotonic(x):
        x1 = x
        sd = np.inf
        while sd > 0.2 or (not isimf(x1)):
            x1 = mirror(x1)
            s1 = getspline(x1)
            s2 = -getspline(-1 * x1)
            x2 = x1 - (s1 + s2) / 2
            x1 = x1[len(x) - 2:-len(x) + 2]
            x2 = x2[len(x) - 2:-len(x) + 2]
            sd = np.sum((x1 - x2) ** 2) / np.sum(x1 ** 2)
            x1 = x2
        imf.append(x1)
        x = x - x1
    imf.append(x)
    return imf

def eemd(x, amp, times, n_modes):
    x = x.reshape(-1)
    imf, n = 0, 0
    for _ in range(times):
        modes = emd(noise(x, amp))
        if len(modes) == n_modes:
            imf += np.array(modes)
            n += 1
    for i in range(len(imf)):
        imf[i] = imf[i] / n
    return imf

# %%
peak = findpeaks(data)
valley = findpeaks(-data)
plt.figure(figsize=(16, 4))
plt.plot(data, c='tab:blue', label='Data')
plt.scatter(peak, data[peak], c='tab:red', marker='^', label='Peaks')
plt.scatter(valley, data[valley], c='tab:green', marker='v', label='Valleys')
plt.plot(getspline(data), c='tab:red', label='Upper Spline')
plt.plot(-getspline(-data), c='tab:green', label='Lower Spline')
plt.plot((getspline(data)-getspline(-data)) / 2, c='tab:orange', label='Average Spline')
plt.legend()
plt.show()

# %%
mirror_data = mirror(data)
peak = findpeaks(mirror_data)
valley = findpeaks(-mirror_data)
upper_spline = getspline(mirror_data)
lower_spline = -getspline(-mirror_data)
plt.figure(figsize=(16, 4))
plt.plot(mirror_data, c='tab:blue', label='Data')
plt.scatter(peak, mirror_data[peak], c='tab:red', marker='^', label='Peaks')
plt.scatter(valley, mirror_data[valley], c='tab:green', marker='v', label='Valleys')
plt.plot(upper_spline, c='tab:red', label='Upper Spline')
plt.plot(lower_spline, c='tab:green', label='Lower Spline')
plt.plot((upper_spline + lower_spline) / 2, c='tab:orange', label='Average Spline')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 4))
noise_data = noise(mirror_data, 400)
upper_spline = getspline(noise_data)
lower_spline = -getspline(-noise_data)
lentgh = len(data)
plt.subplot(1, 2, 1)
plt.plot(noise_data[lentgh-2:-lentgh+2], label='Data')
plt.plot(((upper_spline + lower_spline) / 2)[lentgh-2:-lentgh+2], label='Average Spline')
plt.legend()
for _ in range(99):
    noise_data = noise(mirror_data, 400)
    upper_spline += getspline(noise_data)
    lower_spline += -getspline(-noise_data)
plt.subplot(1, 2, 2)
plt.plot(data, label='Data')
plt.plot(((upper_spline + lower_spline) / 200 )[lentgh-2:-lentgh+2], label='Average Spline')
plt.legend()
plt.show()

# %% [markdown]
# <h3>2.2 資料觀察</h3>
#
#     透過觀察與調整，找出適當的分解參數。
#     停止分解條件，白噪振幅，總體數量，模態數量

# %%
emd_data = emd(d['Actual'])
eemd_data = eemd(d['Actual'], 400, 100, 11)

# %%
plt.figure(figsize=(16, 22))
for n in range(11):
    plt.subplot(11, 2, 2*(n+1)-1)
    plt.plot(emd_data[n])
    plt.subplot(11, 2, 2*(n+1))
    plt.plot(eemd_data[n])
plt.show()

# %%
timesteps = 90
eemd = [np.load(f'EEMD/EEMD{i}.npy').reshape(11, -1, 1) for i in range(1524)]
[i.shape for i in eemd]
# Out:
# [(11, 6065, 1),
#  (11, 6066, 1),
#  (11, 6067, 1),
#  (11, 6068, 1),
#  (11, 6069, 1),
#  (11, 6070, 1),
#  (11, 6071, 1),
#  (11, 6072, 1),
#  (11, 6073, 1),
#  (11, 6074, 1),
#  (11, 6075, 1),
#  (11, 6076, 1),
#  (11, 6077, 1),
#  (11, 6078, 1),
#  (11, 6079, 1),
#  (11, 6080, 1),
#  (11, 6081, 1),
#  (11, 6082, 1),
#  (11, 6083, 1),
#  (11, 6084, 1),
#  (11, 6085, 1),
#  (11, 6086, 1),
#  (11, 6087, 1),
#  (11, 6088, 1),
#  (11, 6089, 1),
#  (11, 6090, 1),
#  (11, 6091, 1),
#  (11, 6092, 1),
#  (11, 6093, 1),
#  (11, 6094, 1),
#  (11, 6095, 1),
#  (11, 6096, 1),
#  (11, 6097, 1),
#  (11, 6098, 1),
#  (11, 6099, 1),
#  (11, 6100, 1),
#  (11, 6101, 1),
#  (11, 6102, 1),
#  (11, 6103, 1),
#  (11, 6104, 1),
#  (11, 6105, 1),
#  (11, 6106, 1),
#  (11, 6107, 1),
#  (11, 6108, 1),
#  (11, 6109, 1),
#  (11, 6110, 1),
#  (11, 6111, 1),
#  (11, 6112, 1),
#  (11, 6113, 1),
#  (11, 6114, 1),
#  (11, 6115, 1),
#  (11, 6116, 1),
#  (11, 6117, 1),
#  (11, 6118, 1),
#  (11, 6119, 1),
#  (11, 6120, 1),
#  (11, 6121, 1),
#  (11, 6122, 1),
#  (11, 6123, 1),
#  (11, 6124, 1),
#  (11, 6125, 1),
#  (11, 6126, 1),
#  (11, 6127, 1),
#  (11, 6128, 1),
#  (11, 6129, 1),
#  (11, 6130, 1),
#  (11, 6131, 1),
#  (11, 6132, 1),
#  (11, 6133, 1),
#  (11, 6134, 1),
#  (11, 6135, 1),
#  (11, 6136, 1),
#  (11, 6137, 1),
#  (11, 6138, 1),
#  (11, 6139, 1),
#  (11, 6140, 1),
#  (11, 6978, 1),
#  (11, 6979, 1),
#  (11, 6980, 1),
#  (11, 6981, 1),
#  (11, 6982, 1),
#  (11, 6983, 1),
#  (11, 6984, 1),
#  (11, 6985, 1),
#  (11, 6986, 1),
#  (11, 6987, 1),
#  (11, 6988, 1),
#  (11, 6989, 1),
#  (11, 6990, 1),
#  (11, 6991, 1),
#  (11, 6992, 1),
#  (11, 6993, 1),
#  (11, 6994, 1),
#  (11, 6995, 1),
#  (11, 6996, 1),
#  (11, 6997, 1),
#  (11, 6998, 1),
#  (11, 6999, 1),
#  (11, 7000, 1),
#  (11, 7001, 1),
#  (11, 7002, 1),
#  (11, 7003, 1),
#  (11, 7004, 1),
#  (11, 7005, 1),
#  (11, 7006, 1),
#  (11, 7007, 1),
#  (11, 7008, 1),
#  (11, 7009, 1),
#  (11, 7010, 1),
#  (11, 7011, 1),
#  (11, 7012, 1),
#  (11, 7013, 1),
#  (11, 7014, 1),
#  (11, 7015, 1),
#  (11, 7016, 1),
#  (11, 7017, 1),
#  (11, 7018, 1),
#  (11, 7019, 1),
#  (11, 7020, 1),
#  (11, 7021, 1),
#  (11, 7022, 1),
#  (11, 7023, 1),
#  (11, 7024, 1),
#  (11, 7025, 1),
#  (11, 7026, 1),
#  (11, 7027, 1),
#  (11, 7028, 1),
#  (11, 7029, 1),
#  (11, 7030, 1),
#  (11, 7031, 1),
#  (11, 7032, 1),
#  (11, 7033, 1),
#  (11, 7034, 1),
#  (11, 7035, 1),
#  (11, 7036, 1),
#  (11, 7037, 1),
#  (11, 7038, 1),
#  (11, 7039, 1),
#  (11, 7040, 1),
#  (11, 7041, 1),
#  (11, 7042, 1),
#  (11, 7043, 1),
#  (11, 7044, 1),
#  (11, 7045, 1),
#  (11, 7046, 1),
#  (11, 7047, 1),
#  (11, 7048, 1),
#  (11, 7049, 1),
#  (11, 7050, 1),
#  (11, 7051, 1),
#  (11, 7052, 1),
#  (11, 7053, 1),
#  (11, 7054, 1),
#  (11, 7055, 1),
#  (11, 7056, 1),
#  (11, 7057, 1),
#  (11, 7058, 1),
#  (11, 7059, 1),
#  (11, 7060, 1),
#  (11, 7061, 1),
#  (11, 7062, 1),
#  (11, 7063, 1),
#  (11, 7064, 1),
#  ...]

# %%
plt.figure(figsize=(16, 22))
for n in range(11):
    plt.subplot(11, 1, n+1)
    for i in eemd[::-2]:
        plt.plot(i[n])
    plt.plot(eemd[0][n], c='tab:blue')
plt.show()

# %% [markdown]
# <h3>3.1 建立模型</h3>
#
#     使用多組不同的超參數，針對不同尺度的模態對模型進行訓練。
#     訓練集、驗證集、測試集，分別使用獨立的分解數據，以杜絕資料洩漏。

# %%
class StandardScaler:
    def __init__(self, data):
        self.mean = np.mean(data)
        self.std = np.std(data)

    def transform(self, data):
        return (data - self.mean) / self.std

    def inverse_transform(self, data):
        return data * self.std + self.mean

# %%
def create_matrixs(mode, eemd, timesteps):
    x_train, y_train = [], []
    for i in range(timesteps, eemd[23][mode].shape[0]):
        x_train.append(eemd[23][mode, i - timesteps:i])
        y_train.append(eemd[23][mode, i])
    x_test, y_test = [], []
    for i in range(23, 1523):
        x_test.append(eemd[i][mode, -timesteps:])
        y_test.append(eemd[i + 1][mode, -1])
    return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

# %%
def split(x_train, y_train, x_test, y_test, seed=42):
    a = np.arange(x_train.shape[0])
    np.random.seed(seed)
    np.random.shuffle(a)
    b = int(x_test.shape[0] * 0.5)
    return x_train[a], y_train[a], x_test[:b], y_test[:b], x_test[b:], y_test[b:]

# %%
def create_model0(shape):
    inputs = Input(shape=(shape[1], shape[2]))
    outputs = Bidirectional(GRU(32, return_sequences=True))(inputs)
    outputs = Bidirectional(GRU(32))(outputs)
    outputs = Dropout(0.5)(outputs)
    outputs = Dense(16, kernel_initializer='he_uniform', kernel_regularizer=l1())(outputs)
    outputs = LeakyReLU(0.1)(outputs)
    outputs = Dense(1, kernel_regularizer=l2())(outputs)
    return Model(inputs=inputs, outputs=outputs)

# %%
def create_model1(shape):
    inputs = Input(shape=(shape[1], shape[2]))
    outputs = Bidirectional(GRU(128, return_sequences=True))(inputs)
    outputs = Bidirectional(GRU(128))(outputs)
    outputs = Dropout(0.5)(outputs)
    outputs = Dense(64, kernel_initializer='he_uniform')(outputs)
    outputs = LeakyReLU(0.1)(outputs)
    outputs = Dense(1, kernel_regularizer=l2())(outputs)
    return Model(inputs=inputs, outputs=outputs)

# %%
def create_model2(shape):
    inputs = Input(shape=(shape[1], shape[2]))
    outputs = Bidirectional(GRU(128, return_sequences=True))(inputs)
    outputs = Bidirectional(GRU(128))(outputs)
    outputs = Dropout(0.5)(outputs)
    outputs = Dense(64)(outputs)
    outputs = Dense(1, kernel_regularizer=l2())(outputs)
    return Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# <h3>3.2 開始訓練</h3>

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
mode = 10
x_train, y_train, x_test, y_test = create_matrixs(mode, eemd, timesteps)
x_train, y_train, x_val, y_val, x_test, y_test = split(x_train, y_train, x_test, y_test)
scaler = StandardScaler(y_train)
d[f'mean{mode}'] = scaler.mean
d[f'std{mode}'] = scaler.std
y_train = scaler.transform(y_train)
x_train = scaler.transform(x_train)
y_val = scaler.transform(y_val)
x_val = scaler.transform(x_val)
x_test = scaler.transform(x_test)
model = create_model2(x_train.shape)
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
filepath = f'{mode}.h5'
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', save_best_only=True)
history0 = model.fit(x_train, y_train, batch_size=512, epochs=100, validation_data=(x_val, y_val), 
                     callbacks=[checkpoint], shuffle=True, verbose=2)
model = load_model(filepath)
model.compile(loss='mean_squared_error', optimizer=SGD(learning_rate=0.001, momentum=0.9))
history1 = model.fit(x_train, y_train, batch_size=512, epochs=50, validation_data=(x_val, y_val), 
                     callbacks=[checkpoint], shuffle=True, verbose=2)
model = load_model(filepath)
model.evaluate(x_val, y_val, verbose=2)
d[f'x_test{mode}'] = x_test
d[f'Predict{mode}'] = scaler.inverse_transform(model.predict(x_test))
d[f'Actual{mode}'] = y_test
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot(d[f'Actual{mode}'], label='Actual')
plt.plot(d[f'Predict{mode}'], label='Predict')
plt.title(f'Predict {mode}')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history0.history['loss'] + history1.history['loss'], label='loss')
plt.plot(history0.history['val_loss'] + history1.history['val_loss'], label='val_loss')
plt.title(f'History {mode}')
plt.legend()
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 90, 256)           100608
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               296448
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 413,569
# Trainable params: 413,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 - 1s - loss: 0.2076 - val_loss: 0.1567
# Epoch 2/100
# 12/12 - 1s - loss: 0.0483 - val_loss: 0.0227
# Epoch 3/100
# 12/12 - 1s - loss: 0.0333 - val_loss: 0.0286
# Epoch 4/100
# 12/12 - 1s - loss: 0.0287 - val_loss: 0.0192
# Epoch 5/100
# 12/12 - 1s - loss: 0.0258 - val_loss: 0.0196
# Epoch 6/100
# 12/12 - 1s - loss: 0.0239 - val_loss: 0.0177
# Epoch 7/100
# 12/12 - 1s - loss: 0.0230 - val_loss: 0.0173
# Epoch 8/100
# 12/12 - 1s - loss: 0.0225 - val_loss: 0.0170
# Epoch 9/100
# 12/12 - 1s - loss: 0.0212 - val_loss: 0.0167
# Epoch 10/100
# 12/12 - 1s - loss: 0.0209 - val_loss: 0.0164
# Epoch 11/100
# 12/12 - 1s - loss: 0.0205 - val_loss: 0.0161
# Epoch 12/100
# 12/12 - 1s - loss: 0.0199 - val_loss: 0.0159
# Epoch 13/100
# 12/12 - 1s - loss: 0.0192 - val_loss: 0.0155
# Epoch 14/100
# 12/12 - 1s - loss: 0.0191 - val_loss: 0.0153
# Epoch 15/100
# 12/12 - 1s - loss: 0.0186 - val_loss: 0.0151
# Epoch 16/100
# 12/12 - 1s - loss: 0.0181 - val_loss: 0.0148
# Epoch 17/100
# 12/12 - 1s - loss: 0.0180 - val_loss: 0.0144
# Epoch 18/100
# 12/12 - 1s - loss: 0.0177 - val_loss: 0.0141
# Epoch 19/100
# 12/12 - 1s - loss: 0.0171 - val_loss: 0.0138
# Epoch 20/100
# 12/12 - 1s - loss: 0.0167 - val_loss: 0.0135
# Epoch 21/100
# 12/12 - 1s - loss: 0.0163 - val_loss: 0.0132
# Epoch 22/100
# 12/12 - 1s - loss: 0.0162 - val_loss: 0.0130
# Epoch 23/100
# 12/12 - 1s - loss: 0.0159 - val_loss: 0.0131
# Epoch 24/100
# 12/12 - 1s - loss: 0.0153 - val_loss: 0.0125
# Epoch 25/100
# 12/12 - 1s - loss: 0.0153 - val_loss: 0.0121
# Epoch 26/100
# 12/12 - 1s - loss: 0.0149 - val_loss: 0.0121
# Epoch 27/100
# 12/12 - 1s - loss: 0.0144 - val_loss: 0.0115
# Epoch 28/100
# 12/12 - 1s - loss: 0.0143 - val_loss: 0.0114
# Epoch 29/100
# 12/12 - 1s - loss: 0.0139 - val_loss: 0.0109
# Epoch 30/100
# 12/12 - 1s - loss: 0.0137 - val_loss: 0.0107
# Epoch 31/100
# 12/12 - 1s - loss: 0.0134 - val_loss: 0.0104
# Epoch 32/100
# 12/12 - 1s - loss: 0.0131 - val_loss: 0.0102
# Epoch 33/100
# 12/12 - 1s - loss: 0.0129 - val_loss: 0.0099
# Epoch 34/100
# 12/12 - 1s - loss: 0.0124 - val_loss: 0.0097
# Epoch 35/100
# 12/12 - 1s - loss: 0.0125 - val_loss: 0.0094
# Epoch 36/100
# 12/12 - 1s - loss: 0.0122 - val_loss: 0.0091
# Epoch 37/100
# 12/12 - 1s - loss: 0.0119 - val_loss: 0.0089
# Epoch 38/100
# 12/12 - 1s - loss: 0.0117 - val_loss: 0.0087
# Epoch 39/100
# 12/12 - 1s - loss: 0.0113 - val_loss: 0.
50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0022
# Epoch 8/50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0021
# Epoch 9/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 10/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0022
# Epoch 11/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 12/50
# 12/12 - 1s - loss: 0.0051 - val_loss: 0.0022
# Epoch 13/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 14/50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0022
# Epoch 15/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 16/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 17/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0022
# Epoch 18/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 19/50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0021
# Epoch 20/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 21/50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0022
# Epoch 22/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 23/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 24/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0022
# Epoch 25/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 26/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0022
# Epoch 27/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 28/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 29/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 30/50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0021
# Epoch 31/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 32/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 33/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 34/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 35/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 36/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 37/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 38/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 39/50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0022
# Epoch 40/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 41/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0022
# Epoch 42/50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0021
# Epoch 43/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# Epoch 44/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 45/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 46/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 47/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 48/50
# 12/12 - 1s - loss: 0.0049 - val_loss: 0.0021
# Epoch 49/50
# 12/12 - 1s - loss: 0.0050 - val_loss: 0.0021
# Epoch 50/50
# 12/12 - 1s - loss: 0.0048 - val_loss: 0.0021
# 24/24 - 0s - loss: 0.0021

# %%
for mode in range(4, 10):
    x_train, y_train, x_test, y_test = create_matrixs(mode, eemd, timesteps)
    x_train, y_train, x_val, y_val, x_test, y_test = split(x_train, y_train, x_test, y_test)
    scaler = StandardScaler(y_train)
    d[f'mean{mode}'] = scaler.mean
    d[f'std{mode}'] = scaler.std
    y_train = scaler.transform(y_train)
    x_train = scaler.transform(x_train)
    y_val = scaler.transform(y_val)
    x_val = scaler.transform(x_val)
    x_test = scaler.transform(x_test)
    model = create_model1(x_train.shape)
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.summary()
    filepath = f'{mode}.h5'
    checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', save_best_only=True)
    history0 = model.fit(x_train, y_train, batch_size=512, epochs=100, validation_data=(x_val, y_val), 
                         callbacks=[checkpoint], shuffle=True, verbose=2)
    model = load_model(filepath)
    model.compile(loss='mean_squared_error', optimizer=SGD(learning_rate=0.001, momentum=0.9))
    history1 = model.fit(x_train, y_train, batch_size=512, epochs=50, validation_data=(x_val, y_val), 
                         callbacks=[checkpoint], shuffle=True, verbose=2)
    model = load_model(filepath)
    model.evaluate(x_val, y_val, verbose=2)
    d[f'x_test{mode}'] = x_test
    d[f'Predict{mode}'] = scaler.inverse_transform(model.predict(x_test))
    d[f'Actual{mode}'] = y_test
    plt.figure(figsize=(16, 4))
    plt.subplot(1, 2, 1)
    plt.plot(d[f'Actual{mode}'], label='Actual')
    plt.plot(d[f'Predict{mode}'], label='Predict')
    plt.title(f'Predict {mode}')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history0.history['loss'] + history1.history['loss'], label='loss')
    plt.plot(history0.history['val_loss'] + history1.history['val_loss'], label='val_loss')
    plt.title(f'History {mode}')
    plt.legend()
    plt.show()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 90, 256)           100608
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 256)               296448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 413,569
# Trainable params: 413,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 - 1s - loss: 0.2893 - val_loss: 0.0229
# Epoch 2/100
# 12/12 - 1s - loss: 0.0876 - val_loss: 0.0269
# Epoch 3/100
# 12/12 - 1s - loss: 0.0609 - val_loss: 0.0211
# Epoch 4/100
# 12/12 - 1s - loss: 0.0470 - val_loss: 0.0206
# Epoch 5/100
# 12/12 - 1s - loss: 0.0379 - val_loss: 0.0199
# Epoch 6/100
# 12/12 - 1s - loss: 0.0339 - val_loss: 0.0189
# Epoch 7/100
# 12/12 - 1s - loss: 0.0318 - val_loss: 0.0184
# Epoch 8/100
# 12/12 - 1s - loss: 0.0287 - val_loss: 0.0182
100
# 12/12 - 1s - loss: 0.0094 - val_loss: 0.0040
# Epoch 94/100
# 12/12 - 1s - loss: 0.0094 - val_loss: 0.0039
# Epoch 95/100
# 12/12 - 1s - loss: 0.0092 - val_loss: 0.0037
# Epoch 96/100
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0037
# Epoch 97/100
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0042
# Epoch 98/100
# 12/12 - 1s - loss: 0.0095 - val_loss: 0.0039
# Epoch 99/100
# 12/12 - 1s - loss: 0.0099 - val_loss: 0.0041
# Epoch 100/100
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0039
# Epoch 1/50
# 12/12 - 1s - loss: 0.0099 - val_loss: 0.0037
# Epoch 2/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0038
# Epoch 3/50
# 12/12 - 1s - loss: 0.0093 - val_loss: 0.0038
# Epoch 4/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0038
# Epoch 5/50
# 12/12 - 1s - loss: 0.0088 - val_loss: 0.0038
# Epoch 6/50
# 12/12 - 1s - loss: 0.0084 - val_loss: 0.0038
# Epoch 7/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0038
# Epoch 8/50
# 12/12 - 1s - loss: 0.0084 - val_loss: 0.0037
# Epoch 9/50
# 12/12 - 1s - loss: 0.0091 - val_loss: 0.0038
# Epoch 10/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0038
# Epoch 11/50
# 12/12 - 1s - loss: 0.0084 - val_loss: 0.0037
# Epoch 12/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0038
# Epoch 13/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0038
# Epoch 14/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0038
# Epoch 15/50
# 12/12 - 1s - loss: 0.0090 - val_loss: 0.0038
# Epoch 16/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0037
# Epoch 17/50
# 12/12 - 1s - loss: 0.0090 - val_loss: 0.0037
# Epoch 18/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0038
# Epoch 19/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0038
# Epoch 20/50
# 12/12 - 1s - loss: 0.0080 - val_loss: 0.0038
# Epoch 21/50
# 12/12 - 1s - loss: 0.0083 - val_loss: 0.0038
# Epoch 22/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0037
# Epoch 23/50
# 12/12 - 1s - loss: 0.0091 - val_loss: 0.0038
# Epoch 24/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0037
# Epoch 25/50
# 12/12 - 1s - loss: 0.0092 - val_loss: 0.0037
# Epoch 26/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0038
# Epoch 27/50
# 12/12 - 1s - loss: 0.0081 - val_loss: 0.0038
# Epoch 28/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0037
# Epoch 29/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0037
# Epoch 30/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0037
# Epoch 31/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0037
# Epoch 32/50
# 12/12 - 1s - loss: 0.0080 - val_loss: 0.0037
# Epoch 33/50
# 12/12 - 1s - loss: 0.0079 - val_loss: 0.0037
# Epoch 34/50
# 12/12 - 1s - loss: 0.0091 - val_loss: 0.0037
# Epoch 35/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0037
# Epoch 36/50
# 12/12 - 1s - loss: 0.0079 - val_loss: 0.0037
# Epoch 37/50
# 12/12 - 1s - loss: 0.0080 - val_loss: 0.0037
# Epoch 38/50
# 12/12 - 1s - loss: 0.0081 - val_loss: 0.0037
# Epoch 39/50
# 12/12 - 1s - loss: 0.0084 - val_loss: 0.0037
# Epoch 40/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0037
# Epoch 41/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0037
# Epoch 42/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0037
# Epoch 43/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0037
# Epoch 44/50
# 12/12 - 1s - loss: 0.0081 - val_loss: 0.0037
# Epoch 45/50
# 12/12 - 1s - loss: 0.0093 - val_loss: 0.0037
# Epoch 46/50
# 12/12 - 1s - loss: 0.0096 - val_loss: 0.0037
# Epoch 47/50
# 12/12 - 1s - loss: 0.0084 - val_loss: 0.0038
# Epoch 48/50
# 12/12 - 1s - loss: 0.0083 - val_loss: 0.0037
# Epoch 49/50
# 12/12 - 1s - loss: 0.0080 - val_loss: 0.0037
# Epoch 50/50
# 12/12 - 1s - loss: 0.0084 - val_loss: 0.0037
# 24/24 - 0s - loss: 0.0037
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 90, 256)           100608
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 256)               296448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                16448
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 413,569
# Trainable params: 413,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 - 1s - loss: 0.2947 - val_loss: 0.0194
# Epoch 2/100
# 12/12 - 1s - loss: 0.0684 - val_loss: 0.0190
# Epoch 3/100
# 12/12 - 1s - loss: 0.0479 - val_loss: 0.0185
# Epoch 4/100
# 12/12 - 1s - loss: 0.0347 - val_loss: 0.0183
# Epoch 5/100
# 12/12 - 1s - loss: 0.0352 - val_loss: 0.0169
# Epoch 6/100
# 12/12 - 1s - loss: 0.0333 - val_loss: 0.0166
# Epoch 7/100
# 12/12 - 1s - loss: 0.0293 - val_loss: 0.0161
# Epoch 8/100
# 12/12 - 1s - loss: 0.0303 - val_loss: 0.0160
# Epoch 9/100
# 12/12 - 1s - loss: 0.0298 - val_loss: 0.0159
# Epoch 10/100
# 12/12 - 1s - loss: 0.0277 - val_loss: 0.0154
# Epoch 11/100
# 12/12 - 1s - loss: 0.0254 - val_loss: 0.0148
# Epoch 12/100
# 12/12 - 1s - loss: 0.0276 - val_loss: 0.0143
# Epoch 13/100
# 12/12 - 1s - loss: 0.0243 - val_loss: 0.0140
# 12/12 - 1s - loss: 0.0091 - val_loss: 0.0022
# Epoch 99/100
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0021
# Epoch 100/100
# 12/12 - 1s - loss: 0.0096 - val_loss: 0.0021
# Epoch 1/50
# 12/12 - 1s - loss: 0.0082 - val_loss: 0.0021
# Epoch 2/50
# 12/12 - 1s - loss: 0.0081 - val_loss: 0.0021
# Epoch 3/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 4/50
# 12/12 - 1s - loss: 0.0088 - val_loss: 0.0021
# Epoch 5/50
# 12/12 - 1s - loss: 0.0079 - val_loss: 0.0021
# Epoch 6/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 7/50
# 12/12 - 1s - loss: 0.0082 - val_loss: 0.0021
# Epoch 8/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0021
# Epoch 9/50
# 12/12 - 1s - loss: 0.0081 - val_loss: 0.0021
# Epoch 10/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0021
# Epoch 11/50
# 12/12 - 1s - loss: 0.0084 - val_loss: 0.0021
# Epoch 12/50
# 12/12 - 1s - loss: 0.0090 - val_loss: 0.0021
# Epoch 13/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0021
# Epoch 14/50
# 12/12 - 1s - loss: 0.0090 - val_loss: 0.0021
# Epoch 15/50
# 12/12 - 1s - loss: 0.0080 - val_loss: 0.0021
# Epoch 16/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 17/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 18/50
# 12/12 - 1s - loss: 0.0091 - val_loss: 0.0021
# Epoch 19/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0021
# Epoch 20/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0021
# Epoch 21/50
# 12/12 - 1s - loss: 0.0082 - val_loss: 0.0021
# Epoch 22/50
# 12/12 - 1s - loss: 0.0091 - val_loss: 0.0021
# Epoch 23/50
# 12/12 - 1s - loss: 0.0081 - val_loss: 0.0021
# Epoch 24/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0021
# Epoch 25/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0021
# Epoch 26/50
# 12/12 - 1s - loss: 0.0082 - val_loss: 0.0021
# Epoch 27/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0021
# Epoch 28/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0021
# Epoch 29/50
# 12/12 - 1s - loss: 0.0089 - val_loss: 0.0021
# Epoch 30/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 31/50
# 12/12 - 1s - loss: 0.0091 - val_loss: 0.0021
# Epoch 32/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 33/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 34/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 35/50
# 12/12 - 1s - loss: 0.0090 - val_loss: 0.0021
# Epoch 36/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0021
# Epoch 37/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0021
# Epoch 38/50
# 12/12 - 1s - loss: 0.0093 - val_loss: 0.0021
# Epoch 39/50
# 12/12 - 1s - loss: 0.0087 - val_loss: 0.0021
# Epoch 40/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0021
# Epoch 41/50
# 12/12 - 1s - loss: 0.0084 - val_loss: 0.0021
# Epoch 42/50
# 12/12 - 1s - loss: 0.0085 - val_loss: 0.0021
# Epoch 43/50
# 12/12 - 1s - loss: 0.0090 - val_loss: 0.0020
# Epoch 44/50
# 12/12 - 1s - loss: 0.0093 - val_loss: 0.0020
# Epoch 45/50
# 12/12 - 1s - loss: 0.0086 - val_loss: 0.0021
# Epoch 46/50
# 12/12 - 1s - loss: 0.0088 - val_loss: 0.0021
# Epoch 47/50
# 12/12 - 1s - loss: 0.0094 - val_loss: 0.0020
# Epoch 48/50
# 12/12 - 1s - loss: 0.0092 - val_loss: 0.0021
# Epoch 49/50
# 12/12 - 1s - loss: 0.0082 - val_loss: 0.0020
# Epoch 50/50
# 12/12 - 1s - loss: 0.0091 - val_loss: 0.0020
# 24/24 - 0s - loss: 0.0020
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 90, 256)           100608
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 256)               296448
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                16448
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 413,569
# Trainable params: 413,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 - 1s - loss: 0.2219 - val_loss: 0.0252
# Epoch 2/100
# 12/12 - 1s - loss: 0.0632 - val_loss: 0.0244
# Epoch 3/100
# 12/12 - 1s - loss: 0.0472 - val_loss: 0.0244
# Epoch 4/100
# 12/12 - 1s - loss: 0.0417 - val_loss: 0.0236
# Epoch 5/100
# 12/12 - 1s - loss: 0.0382 - val_loss: 0.0228
# Epoch 6/100
# 12/12 - 1s - loss: 0.0379 - val_loss: 0.0222
# Epoch 7/100
# 12/12 - 1s - loss: 0.0347 - val_loss: 0.0216
# Epoch 8/100
# 12/12 - 1s - loss: 0.0350 - val_loss: 0.0212
# Epoch 9/100
# 12/12 - 1s - loss: 0.0329 - val_loss: 0.0205
# Epoch 10/100
# 12/12 - 1s - loss: 0.0316 - val_loss: 0.0201
# Epoch 11/100
# 12/12 - 1s - loss: 0.0308 - val_loss: 0.0197
# Epoch 12/100
# 12/12 - 1s - loss: 0.0296 - val_loss: 0.0189
# Epoch 13/100
# 12/12 - 1s - loss: 0.0280 - val_loss: 0.0183
# Epoch 14/100
# 12/12 - 1s - loss: 0.0277 - val_loss: 0.0178
# Epoch 15/100
# 12/12 - 1s - loss: 0.0278 - val_loss: 0.0174
# Epoch 16/100
# 12/12 - 1s - loss: 0.0263 - val_loss: 0.0169
# Epoch 17/100
# 12/12 - 1s - loss: 0.0256 - val_loss: 0.0162
# Epoch 18/100
# 12/12 - 1s - loss: 0.0252 - val_loss: 0.0157
# Epoch 19/100
100
# 12/12 - 1s - loss: 0.0073 - val_loss: 0.0019
# Epoch 97/100
# 12/12 - 1s - loss: 0.0075 - val_loss: 0.0020
# Epoch 98/100
# 12/12 - 1s - loss: 0.0075 - val_loss: 0.0019
# Epoch 99/100
# 12/12 - 1s - loss: 0.0076 - val_loss: 0.0017
# Epoch 100/100
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 1/50
# 12/12 - 1s - loss: 0.0071 - val_loss: 0.0017
# Epoch 2/50
# 12/12 - 1s - loss: 0.0065 - val_loss: 0.0017
# Epoch 3/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 4/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 5/50
# 12/12 - 1s - loss: 0.0070 - val_loss: 0.0017
# Epoch 6/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 7/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 8/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 9/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0017
# Epoch 10/50
# 12/12 - 1s - loss: 0.0064 - val_loss: 0.0017
# Epoch 11/50
# 12/12 - 1s - loss: 0.0070 - val_loss: 0.0017
# Epoch 12/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 13/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0017
# Epoch 14/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0017
# Epoch 15/50
# 12/12 - 1s - loss: 0.0066 - val_loss: 0.0017
# Epoch 16/50
# 12/12 - 1s - loss: 0.0072 - val_loss: 0.0017
# Epoch 17/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 18/50
# 12/12 - 1s - loss: 0.0070 - val_loss: 0.0017
# Epoch 19/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 20/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 21/50
# 12/12 - 1s - loss: 0.0070 - val_loss: 0.0017
# Epoch 22/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 23/50
# 12/12 - 1s - loss: 0.0071 - val_loss: 0.0017
# Epoch 24/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 25/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0017
# Epoch 26/50
# 12/12 - 1s - loss: 0.0071 - val_loss: 0.0017
# Epoch 27/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0017
# Epoch 28/50
# 12/12 - 1s - loss: 0.0072 - val_loss: 0.0017
# Epoch 29/50
# 12/12 - 1s - loss: 0.0070 - val_loss: 0.0017
# Epoch 30/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 31/50
# 12/12 - 1s - loss: 0.0066 - val_loss: 0.0017
# Epoch 32/50
# 12/12 - 1s - loss: 0.0070 - val_loss: 0.0017
# Epoch 33/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 34/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0017
# Epoch 35/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 36/50
# 12/12 - 1s - loss: 0.0066 - val_loss: 0.0017
# Epoch 37/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0017
# Epoch 38/50
# 12/12 - 1s - loss: 0.0070 - val_loss: 0.0017
# Epoch 39/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0017
# Epoch 40/50
# 12/12 - 1s - loss: 0.0065 - val_loss: 0.0017
# Epoch 41/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 42/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0017
# Epoch 43/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 44/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0017
# Epoch 45/50
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0016
# Epoch 46/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0017
# Epoch 47/50
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0016
# Epoch 48/50
# 12/12 - 1s - loss: 0.0070 - val_loss: 0.0017
# Epoch 49/50
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0016
# Epoch 50/50
# 12/12 - 1s - loss: 0.0071 - val_loss: 0.0016
# 24/24 - 0s - loss: 0.0016
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, 90, 256)           100608
# _________________________________________________________________
# bidirectional_11 (Bidirectio (None, 256)               296448
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                16448
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 413,569
# Trainable params: 413,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 - 1s - loss: 0.2200 - val_loss: 0.0291
# Epoch 2/100
# 12/12 - 1s - loss: 0.0562 - val_loss: 0.0160
# Epoch 3/100
# 12/12 - 1s - loss: 0.0354 - val_loss: 0.0169
# Epoch 4/100
# 12/12 - 1s - loss: 0.0310 - val_loss: 0.0154
# Epoch 5/100
# 12/12 - 1s - loss: 0.0269 - val_loss: 0.0151
# Epoch 6/100
# 12/12 - 1s - loss: 0.0243 - val_loss: 0.0148
# Epoch 7/100
# 12/12 - 1s - loss: 0.0236 - val_loss: 0.0148
# Epoch 8/100
# 12/12 - 1s - loss: 0.0225 - val_loss: 0.0145
# Epoch 9/100
# 12/12 - 1s - loss: 0.0223 - val_loss: 0.0142
# Epoch 10/100
# 12/12 - 1s - loss: 0.0208 - val_loss: 0.0141
# Epoch 11/100
# 12/12 - 1s - loss: 0.0202 - val_loss: 0.0141
# Epoch 12/100
# 12/12 - 1s - loss: 0.0202 - val_loss: 0.0140
# Epoch 13/100
# 12/12 - 1s - loss: 0.0191 - val_loss: 0.0135
# Epoch 14/100
# 12/12 - 1s - loss: 0.0190 - val_loss: 0.0131
# Epoch 15/100
# 12/12 - 1s - loss: 0.0189 - val_loss: 0.0130
# Epoch 16/100
# 12/12 - 1s - loss: 0.0180 - val_loss: 0.0127
# Epoch 17/100
# 12/12 - 1s - loss: 0.0174 - val_loss: 0.0123
# Epoch 18/100
# 12/12 - 1s - loss: 0.0175 - val_loss: 0.0120
# Epoch 19/100
# 12/12 - 1s - loss: 0.0170 - val_loss: 0.0118
# Epoch 20/100
# 12/12 - 1s - loss: 0.0165 - val_loss: 0.0120
# Epoch 21/100
# 12/12 - 1s - loss: 0.0162 - val_loss: 0.0116
# Epoch 22/100
# 12/12 - 1s - loss: 0.0154 - val_loss: 0.0114
# Epoch 23/100
# 12/12 - 1s - loss: 0.0157 - val_loss: 0.0108
# Epoch 24/100
# 12/12 - 1s - loss: 0.0157 - val_loss: 0.0106
# Epoch 25/100
# 12/12 - 1s - loss: 0.0156 - val_loss: 0.0108
# Epoch 26/100
# 12/12 - 1s - loss: 0.0150 - val_loss: 0.0108
# Epoch 27/100
# 12/12 - 1s - loss: 0.0145 - val_loss: 0.
100
# 12/12 - 1s - loss: 0.0077 - val_loss: 0.0045
# Epoch 72/100
# 12/12 - 1s - loss: 0.0077 - val_loss: 0.0042
# Epoch 73/100
# 12/12 - 1s - loss: 0.0074 - val_loss: 0.0043
# Epoch 74/100
# 12/12 - 1s - loss: 0.0075 - val_loss: 0.0046
# Epoch 75/100
# 12/12 - 1s - loss: 0.0073 - val_loss: 0.0041
# Epoch 76/100
# 12/12 - 1s - loss: 0.0073 - val_loss: 0.0041
# Epoch 77/100
# 12/12 - 1s - loss: 0.0073 - val_loss: 0.0048
# Epoch 78/100
# 12/12 - 1s - loss: 0.0072 - val_loss: 0.0038
# Epoch 79/100
# 12/12 - 1s - loss: 0.0073 - val_loss: 0.0041
# Epoch 80/100
# 12/12 - 1s - loss: 0.0072 - val_loss: 0.0036
# Epoch 81/100
# 12/12 - 1s - loss: 0.0072 - val_loss: 0.0046
# Epoch 82/100
# 12/12 - 1s - loss: 0.0072 - val_loss: 0.0038
# Epoch 83/100
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0038
# Epoch 84/100
# 12/12 - 1s - loss: 0.0067 - val_loss: 0.0040
# Epoch 85/100
# 12/12 - 1s - loss: 0.0065 - val_loss: 0.0037
# Epoch 86/100
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0038
# Epoch 87/100
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0036
# Epoch 88/100
# 12/12 - 1s - loss: 0.0069 - val_loss: 0.0036
# Epoch 89/100
# 12/12 - 1s - loss: 0.0073 - val_loss: 0.0035
# Epoch 90/100
# 12/12 - 1s - loss: 0.0068 - val_loss: 0.0039
# Epoch 91/100
# 12/12 - 1s - loss: 0.0065 - val_loss: 0.0040
# Epoch 92/100
# 12/12 - 1s - loss: 0.0065 - val_loss: 0.0039
# Epoch 93/100
# 12/12 - 1s - loss: 0.0066 - val_loss: 0.0037
# Epoch 94/100
# 12/12 - 1s - loss: 0.0066 - val_loss: 0.0040
# Epoch 95/100
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 96/100
# 12/12 - 1s - loss: 0.0065 - val_loss: 0.0036
# Epoch 97/100
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0036
# Epoch 98/100
# 12/12 - 1s - loss: 0.0064 - val_loss: 0.0033
# Epoch 99/100
# 12/12 - 1s - loss: 0.0064 - val_loss: 0.0035
# Epoch 100/100
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0034
# Epoch 1/50
# 12/12 - 1s - loss: 0.0064 - val_loss: 0.0035
# Epoch 2/50
# 12/12 - 1s - loss: 0.0064 - val_loss: 0.0037
# Epoch 3/50
# 12/12 - 1s - loss: 0.0060 - val_loss: 0.0036
# Epoch 4/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0036
# Epoch 5/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 6/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 7/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 8/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 9/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0036
# Epoch 10/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0035
# Epoch 11/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0037
# Epoch 12/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0037
# Epoch 13/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0035
# Epoch 14/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 15/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0037
# Epoch 16/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0037
# Epoch 17/50
# 12/12 - 1s - loss: 0.0060 - val_loss: 0.0036
# Epoch 18/50
# 12/12 - 1s - loss: 0.0065 - val_loss: 0.0036
# Epoch 19/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0037
# Epoch 20/50
# 12/12 - 1s - loss: 0.0060 - val_loss: 0.0037
# Epoch 21/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 22/50
# 12/12 - 1s - loss: 0.0060 - val_loss: 0.0036
# Epoch 23/50
# 12/12 - 1s - loss: 0.0060 - val_loss: 0.0036
# Epoch 24/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 25/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 26/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0037
# Epoch 27/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0037
# Epoch 28/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 29/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 30/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0036
# Epoch 31/50
# 12/12 - 1s - loss: 0.0060 - val_loss: 0.0036
# Epoch 32/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0035
# Epoch 33/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0036
# Epoch 34/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 35/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0036
# Epoch 36/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 37/50
# 12/12 - 1s - loss: 0.0060 - val_loss: 0.0036
# Epoch 38/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 39/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 40/50
# 12/12 - 1s - loss: 0.0059 - val_loss: 0.0035
# Epoch 41/50
# 12/12 - 1s - loss: 0.0063 - val_loss: 0.0037
# Epoch 42/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0037
# Epoch 43/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 44/50
# 12/12 - 1s - loss: 0.0059 - val_loss: 0.0036
# Epoch 45/50
# 12/12 - 1s - loss: 0.0060 - val_loss: 0.0036
# Epoch 46/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# Epoch 47/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0036
# Epoch 48/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0035
# Epoch 49/50
# 12/12 - 1s - loss: 0.0061 - val_loss: 0.0037
# Epoch 50/50
# 12/12 - 1s - loss: 0.0062 - val_loss: 0.0036
# 24/24 - 0s - loss: 0.0033
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_12 (Bidirectio (None, 90, 256)           100608
# _________________________________________________________________
# bidirectional_13 (Bidirectio (None, 256)               296448
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                16448
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 413,569
# Trainable params: 413,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 - 1s - loss: 0.2293 - val_loss: 0.0297
# Epoch 2/100
# 12/12 - 1s - loss: 0.0538 - val_loss: 0.0185
# Epoch 3/100
# 12/12 - 1s - loss: 0.0334 - val_loss: 0.0187
# Epoch 4/100
# 12/12 - 1s - loss: 0.0292 - val_loss: 0.0171
# Epoch 5/100
# 12/12 - 1s - loss: 0.0263 - val_loss: 0.0174
# Epoch 6/100
# 12/12 - 1s - loss: 0.0245 - val_loss: 0.0168
# Epoch 7/100
# 12/12 - 1s - loss: 0.0235 - val_loss: 0.0169
# Epoch 8/100
# 12/12 - 1s - loss: 0.0230 - val_loss: 0.0165
# Epoch 9/100
# 12/12 - 1s - loss: 0.0217 - val_loss: 0.0162
# Epoch 10/100
# 12/12 - 1s - loss: 0.0214 - val_loss: 0.0160
# Epoch 11/100
# 12/12 - 1s - loss: 0.0209 - val_loss: 0.0158
# Epoch 12/100
# 12/12 - 1s - loss: 0.0203 - val_loss: 0.0160
# Epoch 13/100
50
# 12/12 - 1s - loss: 0.0057 - val_loss: 0.0034
# Epoch 14/50
# 12/12 - 1s - loss: 0.0057 - val_loss: 0.0035
# Epoch 15/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0035
# Epoch 16/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 17/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0034
# Epoch 18/50
# 12/12 - 1s - loss: 0.0058 - val_loss: 0.0034
# Epoch 19/50
# 12/12 - 1s - loss: 0.0058 - val_loss: 0.0034
# Epoch 20/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0035
# Epoch 21/50
# 12/12 - 1s - loss: 0.0057 - val_loss: 0.0034
# Epoch 22/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 23/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 24/50
# 12/12 - 1s - loss: 0.0054 - val_loss: 0.0034
# Epoch 25/50
# 12/12 - 1s - loss: 0.0058 - val_loss: 0.0034
# Epoch 26/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 27/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0034
# Epoch 28/50
# 12/12 - 1s - loss: 0.0059 - val_loss: 0.0035
# Epoch 29/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0035
# Epoch 30/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0035
# Epoch 31/50
# 12/12 - 1s - loss: 0.0057 - val_loss: 0.0034
# Epoch 32/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0034
# Epoch 33/50
# 12/12 - 1s - loss: 0.0057 - val_loss: 0.0034
# Epoch 34/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0035
# Epoch 35/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0035
# Epoch 36/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 37/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0034
# Epoch 38/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 39/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0034
# Epoch 40/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0035
# Epoch 41/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0035
# Epoch 42/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 43/50
# 12/12 - 1s - loss: 0.0055 - val_loss: 0.0035
# Epoch 44/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 45/50
# 12/12 - 1s - loss: 0.0054 - val_loss: 0.0034
# Epoch 46/50
# 12/12 - 1s - loss: 0.0054 - val_loss: 0.0034
# Epoch 47/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0033
# Epoch 48/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0035
# Epoch 49/50
# 12/12 - 1s - loss: 0.0056 - val_loss: 0.0034
# Epoch 50/50
# 12/12 - 1s - loss: 0.0054 - val_loss: 0.0034
# 24/24 - 0s - loss: 0.0032

# %%
for mode in range(4):
    x_train, y_train, x_test, y_test = create_matrixs(mode, eemd, timesteps)
    x_train, y_train, x_val, y_val, x_test, y_test = split(x_train, y_train, x_test, y_test)
    scaler = StandardScaler(y_train)
    d[f'mean{mode}'] = scaler.mean
    d[f'std{mode}'] = scaler.std
    y_train = scaler.transform(y_train)
    x_train = scaler.transform(x_train)
    y_val = scaler.transform(y_val)
    x_val = scaler.transform(x_val)
    x_test = scaler.transform(x_test)
    model = create_model0(x_train.shape)
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.summary()
    filepath = f'{mode}.h5'
    checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', save_best_only=True)
    history0 = model.fit(x_train, y_train, batch_size=512, epochs=50, validation_data=(x_val, y_val), 
                         callbacks=[checkpoint], shuffle=True, verbose=2)
    model = load_model(filepath)
    model.compile(loss='mean_squared_error', optimizer=SGD(learning_rate=0.001, momentum=0.9))
    history1 = model.fit(x_train, y_train, batch_size=512, epochs=50, validation_data=(x_val, y_val),
                         callbacks=[checkpoint], shuffle=True, verbose=2)
    model = load_model(filepath)
    model.evaluate(x_val, y_val, verbose=2)
    d[f'x_test{mode}'] = x_test
    d[f'Predict{mode}'] = scaler.inverse_transform(model.predict(x_test))
    d[f'Actual{mode}'] = y_test
    plt.figure(figsize=(16, 4))
    plt.subplot(1, 2, 1)
    plt.plot(d[f'Actual{mode}'], label='Actual')
    plt.plot(d[f'Predict{mode}'], label='Predict')
    plt.title(f'Predict {mode}')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history0.history['loss'] + history1.history['loss'], label='loss')
    plt.plot(history0.history['val_loss'] + history1.history['val_loss'], label='val_loss')
    plt.title(f'History {mode}')
    plt.legend()
    plt.show()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_14 (Bidirectio (None, 90, 64)            6720
# _________________________________________________________________
# bidirectional_15 (Bidirectio (None, 64)                18816
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                1040
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 26,593
# Trainable params: 26,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 12/12 - 1s - loss: 2.4825 - val_loss: 2.6195
# Epoch 2/50
# 12/12 - 0s - loss: 2.2763 - val_loss: 2.6122
# Epoch 3/50
# 12/12 - 0s - loss: 2.0983 - val_loss: 2.6662
# Epoch 4/50
# 12/12 - 0s - loss: 1.9805 - val_loss: 2.5672
# Epoch 5/50
# 12/12 - 0s - loss: 1.8651 - val_loss: 2.4239
# Epoch 6/50
# 12/12 - 0s - loss: 1.7636 - val_loss: 2.3278
# Epoch 7/50
# 12/12 - 0s - loss: 1.6797 - val_loss: 2.2469
# Epoch 8/50
# 12/12 - 0s - loss: 1.5817 - val_loss: 2.1514
# Epoch 9/50
# 12/12 - 0s - loss: 1.4940 - val_loss: 2.0590
# Epoch 10/50
# 12/12 - 0s - loss: 1.4156 - val_loss: 1.9919
# Epoch 11/50
# 12/12 - 0s - loss: 1.3528 - val_loss: 1.9235
# Epoch 12/50
# 12/12 - 0s - loss: 1.2739 - val_loss: 1.8455
# Epoch 13/50
# 12/12 - 0s - loss: 1.2232 - val_loss: 1.8108
# Epoch 14/50
# 12/12 - 0s - loss: 1.1629 - val_loss: 1.7418
# Epoch 15/50
# 12/12 - 0s - loss: 1.1097 - val_loss: 1.7025
# Epoch 16/50
# 12/12 - 0s - loss: 1.0620 - val_loss: 1.6535
# Epoch 17/50
# 12/12 - 0s - loss: 1.0219 - val_loss: 1.6180
# Epoch 18/50
# 12/12 - 0s - loss: 0.9804 - val_loss: 1.5841
# Epoch 19/50
# 12/12 - 0s - loss: 0.9442 - val_loss: 1.5465
# Epoch 20/50
# 12/12 - 0s - loss: 0.9089 - val_loss: 1.5335
# Epoch 21/50
# 12/12 - 0s - loss: 0.8855 - val_loss: 1.5006
# Epoch 22/50
# 12/12 - 0s - loss: 0.8722 - val_loss: 1.4769
# Epoch 23/50
# 12/12 - 0s - loss: 0.8430 - val_loss: 1.4459
# Epoch 24/50
# 12/12 - 0s - loss: 0.8246 - val_loss: 1.4370
# Epoch 25/50
# 12/12 - 0s - loss: 0.8001 - val_loss: 1.4290
# Epoch 26/50
# 12/12 - 0s - loss: 0.7980 - val_loss: 1.4037
# Epoch 27/50
# 12/12 - 0s - loss: 0.7964 - val_loss: 1.4119
# Epoch 28/50
# 12/12 - 0s - loss: 0.7955 - val_loss: 1.4112
# Epoch 29/50
# 12/12 - 0s - loss: 0.7899 - val_loss: 1.4198
# Epoch 30/50
# 12/12 - 0s - loss: 0.7722 - val_loss: 1.4152
# Epoch 31/50
# 12/12 - 0s - loss: 0.7810 - val_loss: 1.4130
# Epoch 32/50
# 12/12 - 0s - loss: 0.7757 - val_loss: 1.4073
# Epoch 33/50
# 12/12 - 0s - loss: 0.7757 - val_loss: 1.4120
# Epoch 34/50
# 12/12 - 0s - loss: 0.7762 - val_loss: 1.3851
# Epoch 35/50
# 12/12 - 0s - loss: 0.7701 - val_loss: 1.4115
# Epoch 36/50
# 12/12 - 0s - loss: 0.7714 - val_loss: 1.4049
# Epoch 37/50
# 12/12 - 0s - loss: 0.7607 - val_loss: 1.4036
# Epoch 38/50
# 12/12 - 0s - loss: 0.7714 - val_loss: 1.3954
# Epoch 39/50
# 12/12 - 0s - loss: 0.7689 - val_loss: 1.4176
# Epoch 40/50
# 12/12 - 0s - loss: 0.7618 - val_loss: 1.4060
# Epoch 41/50
# 12/12 - 0s - loss: 0.7599 - val_loss: 1.3985
# Epoch 42/50
# 12/12 - 0s - loss: 0.7588 - val_loss: 1.4097
# Epoch 43/50
# 12/12 - 0s - loss: 0.7470 - val_loss: 1.4211
# Epoch 44/50
# 12/12 - 0s - loss: 0.7520 - val_loss: 1.3929
# Epoch 45/50
# 12/12 - 0s - loss: 0.7590 - val_loss: 1.4045
# Epoch 46/50
# 12/12 - 0s - loss: 0.7629 - val_loss: 1.4302
# Epoch 47/50
# 12/12 - 0s - loss: 0.7478 - val_loss: 1.4057
# Epoch 48/50
# 12/12 - 0s - loss: 0.7508 - val_loss: 1.4119
# Epoch 49/50
# 12/12 - 0s - loss: 0.7511 - val_loss: 1.4092
# Epoch 50/50
# 12/12 - 0s - loss: 0.7531 - val_loss: 1.4078
# Epoch 1/50
# 12/12 - 1s - loss: 0.7653 - val_loss: 1.3883
# Epoch 2/50
# 12/12 - 0s - loss: 0.7714 - val_loss: 1.3878
# Epoch 3/50
# 12/12 - 0s - loss: 0.7599 - val_loss: 1.3908
# Epoch 4/50
# 12/12 - 0s - loss: 0.7706 - val_loss: 1.3934
# Epoch 5/50
# 12/12 - 0s - loss: 0.7639 - val_loss: 1.3954
# Epoch 6/50
# 12/12 - 0s - loss: 0.7653 - val_loss: 1.3937
# Epoch 7/50
# 12/12 - 0s - loss: 0.7706 - val_loss: 1.3916
# Epoch 8/50
# 12/12 - 0s - loss: 0.7655 - val_loss: 1.3906
# Epoch 9/50
# 12/12 - 0s - loss: 0.7620 - val_loss: 1.3910
# Epoch 10/50
# 12/12 - 0s - loss: 0.7679 - val_loss: 1.3936
# Epoch 11/50
# 12/12 - 0s - loss: 0.7638 - val_loss: 1.3948
# Epoch 12/50
# 12/12 - 0s - loss: 0.7675 - val_loss: 1.3957
# Epoch 13/50
# 12/12 - 0s - loss: 0.7528 - val_loss: 1.3992
# Epoch 14/50
# 12/12 - 0s - loss: 0.7560 - val_loss: 1.4014
# Epoch 15/50
# 12/12 - 0s - loss: 0.7638 - val_loss: 1.3979
# Epoch 16/50
# 12/12 - 0s - loss: 0.7674 - val_loss: 1.3980
# Epoch 17/50
# 12/12 - 0s - loss: 0.7638 - val_loss: 1.3950
# Epoch 18/50
# 12/12 - 0s - loss: 0.7616 - val_loss: 1.3969
# Epoch 19/50
# 12/12 - 0s - loss: 0.7634 - val_loss: 1.4016
# Epoch 20/50
# 12/12 - 0s - loss: 0.7564 - val_loss: 1.4037
# Epoch 21/50
# 12/12 - 0s - loss: 0.7592 - val_loss: 1.4020
# Epoch 22/50
# 12/12 - 0s - loss: 0.7629 - val_loss: 1.3974
# Epoch 23/50
# 12/12 - 0s - loss: 0.7580 - val_loss: 1.3953
# Epoch 24/50
# 12/12 - 0s - loss: 0.7547 - val_loss: 1.3926
# Epoch 25/50
# 12/12 - 0s - loss: 0.7592 - val_loss: 1.3959
# Epoch 26/50
# 12/12 - 0s - loss: 0.7519 - val_loss: 1.3978
# Epoch 27/50
# 12/12 - 0s - loss: 0.7618 - val_loss: 1.3971
# Epoch 28/50
# 12/12 - 0s - loss: 0.7533 - val_loss: 1.3962
# Epoch 29/50
# 12/12 - 0s - loss: 0.7543 - val_loss: 1.3998
# Epoch 30/50
# 12/12 - 0s - loss: 0.7564 - val_loss: 1.3998
# Epoch 31/50
# 12/12 - 0s - loss: 0.7470 - val_loss: 1.4026
# Epoch 32/50
# 12/12 - 0s - loss: 0.7595 - val_loss: 1.3981
# Epoch 33/50
# 12/12 - 0s - loss: 0.7548 - val_loss: 1.3984
# Epoch 34/50
# 12/12 - 0s - loss: 0.7527 - val_loss: 1.3990
# Epoch 35/50
# 12/12 - 0s - loss: 0.7600 - val_loss: 1.3962
# Epoch 36/50
# 12/12 - 0s - loss: 0.7633 - val_loss: 1.3946
# Epoch 37/50
# 12/12 - 0s - loss: 0.7480 - val_loss: 1.3936
# Epoch 38/50
# 12/12 - 0s - loss: 0.7606 - val_loss: 1.3955
# Epoch 39/50
# 12/12 - 0s - loss: 0.7507 - val_loss: 1.3935
# Epoch 40/50
# 12/12 - 0s - loss: 0.7484 - val_loss: 1.3969
# Epoch 41/50
# 12/12 - 0s - loss: 0.7507 - val_loss: 1.3975
# Epoch 42/50
# 12/12 - 0s - loss: 0.7549 - val_loss: 1.3955
# Epoch 43/50
# 12/12 - 0s - loss: 0.7533 - val_loss: 1.3958
# Epoch 44/50
# 12/12 - 0s - loss: 0.7493 - val_loss: 1.3949
# Epoch 45/50
# 12/12 - 0s - loss: 0.7591 - val_loss: 1.3967
# Epoch 46/50
# 12/12 - 0s - loss: 0.7628 - val_loss: 1.3988
# Epoch 47/50
# 12/12 - 0s - loss: 0.7524 - val_loss: 1.3963
# Epoch 48/50
# 12/12 - 0s - loss: 0.7551 - val_loss: 1.3936
# Epoch 49/50
# 12/12 - 0s - loss: 0.7548 - val_loss: 1.3950
# Epoch 50/50
# 12/12 - 0s - loss: 0.7529 - val_loss: 1.3917
# 24/24 - 0s - loss: 1.3851
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_16 (Bidirectio (None, 90, 64)            6720
# _________________________________________________________________
# bidirectional_17 (Bidirectio (None, 64)                18816
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 16)                1040
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 26,593
# Trainable params: 26,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 12/12 - 1s - loss: 2.4262 - val_loss: 1.9943
# Epoch 2/50
# 12/12 - 0s - loss: 2.2046 - val_loss: 1.8416
# Epoch 3/50
# 12/12 - 0s - loss: 1.9652 - val_loss: 1.7093
# Epoch 4/50
# 12/12 - 0s - loss: 1.7494 - val_loss: 1.6070
# Epoch 5/50
# 12/12 - 0s - loss: 1.5977 - val_loss: 1.5133
# Epoch 6/50
# 12/12 - 0s - loss: 1.4694 - val_loss: 1.4191
# Epoch 7/50
# 12/12 - 0s - loss: 1.3443 - val_loss: 1.3423
# Epoch 8/50
# 12/12 - 0s - loss: 1.2220 - val_loss: 1.2713
# Epoch 9/50
# 12/12 - 0s - loss: 1.1116 - val_loss: 1.2116
# Epoch 10/50
# 12/12 - 0s - loss: 1.0080 - val_loss: 1.1495
# Epoch 11/50
# 12/12 - 0s - loss: 0.9148 - val_loss: 1.0903
# Epoch 12/50
# 12/12 - 0s - loss: 0.8261 - val_loss: 1.0367
# Epoch 13/50
# 12/12 - 0s - loss: 0.7527 - val_loss: 0.9874
# Epoch 14/50
# 12/12 - 0s - loss: 0.6929 - val_loss: 0.9363
# Epoch 15/50
# 12/12 - 0s - loss: 0.6289 - val_loss: 0.8972
# Epoch 16/50
# 12/12 - 0s - loss: 0.5840 - val_loss: 0.8493
# Epoch 17/50
# 12/12 - 0s - loss: 0.5315 - val_loss: 0.8089
# Epoch 18/50
# 12/12 - 0s - loss: 0.4893 - val_loss: 0.7789
# Epoch 19/50
# 12/12 - 0s - loss: 0.4531 - val_loss: 0.7519
# Epoch 20/50
# 12/12 - 0s - loss: 0.4268 - val_loss: 0.7153
# Epoch 21/50
# 12/12 - 0s - loss: 0.4019 - val_loss: 0.7035
# Epoch 22/50
# 12/12 - 0s - loss: 0.3791 - val_loss: 0.6798
# Epoch 23/50
# 12/12 - 0s - loss: 0.3557 - val_loss: 0.6630
# Epoch 24/50
# 12/12 - 0s - loss: 0.3433 - val_loss: 0.6496
# Epoch 25/50
# 12/12 - 0s - loss: 0.3337 - val_loss: 0.6432
# Epoch 26/50
# 12/12 - 0s - loss: 0.3365 - val_loss: 0.6344
# Epoch 27/50
# 12/12 - 0s - loss: 0.3176 - val_loss: 0.6313
# Epoch 28/50
# 12/12 - 0s - loss: 0.3132 - val_loss: 0.6221
# Epoch 29/50
# 12/12 - 0s - loss: 0.3092 - val_loss: 0.6218
# Epoch 30/50
# 12/12 - 0s - loss: 0.3022 - val_loss: 0.6212
# Epoch 31/50
# 12/12 - 0s - loss: 0.3058 - val_loss: 0.6122
# Epoch 32/50
# 12/12 - 0s - loss: 0.2904 - val_loss: 0.6169
# Epoch 33/50
# 12/12 - 0s - loss: 0.2968 - val_loss: 0.6137
# Epoch 34/50
# 12/12 - 0s - loss: 0.2859 - val_loss: 0.6116
# Epoch 35/50
# 12/12 - 0s - loss: 0.2895 - val_loss: 0.6106
# Epoch 36/50
# 12/12 - 0s - loss: 0.2875 - val_loss: 0.6056
# Epoch 37/50
# 12/12 - 0s - loss: 0.2839 - val_loss: 0.6117
# Epoch 38/50
# 12/12 - 0s - loss: 0.2884 - val_loss: 0.6012
# Epoch 39/50
# 12/12 - 0s - loss: 0.2863 - val_loss: 0.6073
# Epoch 40/50
# 12/12 - 0s - loss: 0.2833 - val_loss: 0.6063
# Epoch 41/50
# 12/12 - 0s - loss: 0.2839 - val_loss: 0.6023
# Epoch 42/50
# 12/12 - 0s - loss: 0.2771 - val_loss: 0.6019
# Epoch 43/50
# 12/12 - 0s - loss: 0.2727 - val_loss: 0.6010
# Epoch 44/50
# 12/12 - 0s - loss: 0.2722 - val_loss: 0.5973
# Epoch 45/50
# 12/12 - 0s - loss: 0.2657 - val_loss: 0.6021
# Epoch 46/50
# 12/12 - 0s - loss: 0.2792 - val_loss: 0.6007
# Epoch 47/50
# 12/12 - 0s - loss: 0.2711 - val_loss: 0.6044
# Epoch 48/50
# 12/12 - 0s - loss: 0.2704 - val_loss: 0.5955
# Epoch 49/50
# 12/12 - 0s - loss: 0.2707 - val_loss: 0.5954
# Epoch 50/50
# 12/12 - 0s - loss: 0.2651 - val_loss: 0.5976
# Epoch 1/50
# 12/12 - 1s - loss: 0.2688 - val_loss: 0.5947
# Epoch 2/50
# 12/12 - 0s - loss: 0.2594 - val_loss: 0.5944
# Epoch 3/50
# 12/12 - 0s - loss: 0.2660 - val_loss: 0.5943
# Epoch 4/50
# 12/12 - 1s - loss: 0.2614 - val_loss: 0.5940
# Epoch 5/50
# 12/12 - 0s - loss: 0.2588 - val_loss: 0.5939
# Epoch 6/50
# 12/12 - 0s - loss: 0.2740 - val_loss: 0.5937
# Epoch 7/50
# 12/12 - 0s - loss: 0.2596 - val_loss: 0.5937
# Epoch 8/50
# 12/12 - 0s - loss: 0.2588 - val_loss: 0.5931
# Epoch 9/50
# 12/12 - 0s - loss: 0.2645 - val_loss: 0.5929
# Epoch 10/50
# 12/12 - 0s - loss: 0.2612 - val_loss: 0.5943
# Epoch 11/50
# 12/12 - 0s - loss: 0.2626 - val_loss: 0.5940
# Epoch 12/50
# 12/12 - 0s - loss: 0.2560 - val_loss: 0.5935
# Epoch 13/50
# 12/12 - 0s - loss: 0.2550 - val_loss: 0.5925
# Epoch 14/50
# 12/12 - 0s - loss: 0.2609 - val_loss: 0.5926
# Epoch 15/50
# 12/12 - 0s - loss: 0.2635 - val_loss: 0.5922
# Epoch 16/50
# 12/12 - 0s - loss: 0.2592 - val_loss: 0.5915
# Epoch 17/50
# 12/12 - 0s - loss: 0.2554 - val_loss: 0.5921
# Epoch 18/50
# 12/12 - 0s - loss: 0.2464 - val_loss: 0.5924
# Epoch 19/50
# 12/12 - 0s - loss: 0.2476 - val_loss: 0.5919
# Epoch 20/50
# 12/12 - 0s - loss: 0.2511 - val_loss: 0.5911
# Epoch 21/50
# 12/12 - 0s - loss: 0.2542 - val_loss: 0.5909
# Epoch 22/50
# 12/12 - 0s - loss: 0.2531 - val_loss: 0.5907
# Epoch 23/50
# 12/12 - 0s - loss: 0.2554 - val_loss: 0.5911
# Epoch 24/50
# 12/12 - 0s - loss: 0.2513 - val_loss: 0.5908
# Epoch 25/50
# 12/12 - 0s - loss: 0.2480 - val_loss: 0.5903
# Epoch 26/50
# 12/12 - 0s - loss: 0.2543 - val_loss: 0.5894
# Epoch 27/50
# 12/12 - 0s - loss: 0.2546 - val_loss: 0.5902
# Epoch 28/50
# 12/12 - 0s - loss: 0.2563 - val_loss: 0.5899
# Epoch 29/50
# 12/12 - 0s - loss: 0.2572 - val_loss: 0.5905
# Epoch 30/50
# 12/12 - 0s - loss: 0.2465 - val_loss: 0.5897
# Epoch 31/50
# 12/12 - 0s - loss: 0.2586 - val_loss: 0.5897
# Epoch 32/50
# 12/12 - 0s - loss: 0.2452 - val_loss: 0.5900
# Epoch 33/50
# 12/12 - 0s - loss: 0.2475 - val_loss: 0.5888
# Epoch 34/50
# 12/12 - 0s - loss: 0.2539 - val_loss: 0.5893
# Epoch 35/50
# 12/12 - 0s - loss: 0.2516 - val_loss: 0.5898
# Epoch 36/50
# 12/12 - 0s - loss: 0.2411 - val_loss: 0.5889
# Epoch 37/50
# 12/12 - 0s - loss: 0.2506 - val_loss: 0.5890
# Epoch 38/50
# 12/12 - 0s - loss: 0.2516 - val_loss: 0.5886
# Epoch 39/50
# 12/12 - 0s - loss: 0.2512 - val_loss: 0.5880
# Epoch 40/50
# 12/12 - 0s - loss: 0.2457 - val_loss: 0.5870
# Epoch 41/50
# 12/12 - 0s - loss: 0.2462 - val_loss: 0.5864
# Epoch 42/50
# 12/12 - 0s - loss: 0.2476 - val_loss: 0.5862
# Epoch 43/50
# 12/12 - 0s - loss: 0.2432 - val_loss: 0.5870
# Epoch 44/50
# 12/12 - 0s - loss: 0.2522 - val_loss: 0.5881
# Epoch 45/50
# 12/12 - 0s - loss: 0.2432 - val_loss: 0.5878
# Epoch 46/50
# 12/12 - 0s - loss: 0.2474 - val_loss: 0.5873
# Epoch 47/50
# 12/12 - 0s - loss: 0.2513 - val_loss: 0.5870
# Epoch 48/50
# 12/12 - 0s - loss: 0.2461 - val_loss: 0.5867
# Epoch 49/50
# 12/12 - 0s - loss: 0.2489 - val_loss: 0.5863
# Epoch 50/50
# 12/12 - 0s - loss: 0.2435 - val_loss: 0.5859
# 24/24 - 0s - loss: 0.5859
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, 90, 64)            6720
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, 64)                18816
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                1040
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 26,593
# Trainable params: 26,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 12/12 - 1s - loss: 2.3832 - val_loss: 1.6743
# Epoch 2/50
# 12/12 - 0s - loss: 2.0206 - val_loss: 1.5269
# Epoch 3/50
# 12/12 - 0s - loss: 1.7509 - val_loss: 1.4257
# Epoch 4/50
# 12/12 - 0s - loss: 1.5506 - val_loss: 1.3522
# Epoch 5/50
# 12/12 - 0s - loss: 1.4173 - val_loss: 1.2701
# Epoch 6/50
# 12/12 - 0s - loss: 1.3182 - val_loss: 1.1794
# Epoch 7/50
# 12/12 - 0s - loss: 1.2190 - val_loss: 1.1032
# Epoch 8/50
# 12/12 - 0s - loss: 1.1234 - val_loss: 1.0270
# Epoch 9/50
# 12/12 - 0s - loss: 1.0412 - val_loss: 0.9571
# Epoch 10/50
# 12/12 - 0s - loss: 0.9584 - val_loss: 0.8854
# Epoch 11/50
# 12/12 - 0s - loss: 0.8844 - val_loss: 0.8172
# Epoch 12/50
# 12/12 - 0s - loss: 0.8082 - val_loss: 0.7553
# Epoch 13/50
# 12/12 - 0s - loss: 0.7549 - val_loss: 0.6946
# Epoch 14/50
# 12/12 - 0s - loss: 0.6777 - val_loss: 0.6357
# Epoch 15/50
# 12/12 - 0s - loss: 0.6268 - val_loss: 0.5839
# Epoch 16/50
# 12/12 - 0s - loss: 0.5648 - val_loss: 0.5327
# Epoch 17/50
# 12/12 - 0s - loss: 0.5258 - val_loss: 0.4906
# Epoch 18/50
# 12/12 - 0s - loss: 0.4794 - val_loss: 0.4489
# Epoch 19/50
# 12/12 - 0s - loss: 0.4349 - val_loss: 0.4125
# Epoch 20/50
# 12/12 - 0s - loss: 0.4018 - val_loss: 0.3855
# Epoch 21/50
# 12/12 - 0s - loss: 0.3725 - val_loss: 0.3519
# Epoch 22/50
# 12/12 - 0s - loss: 0.3425 - val_loss: 0.3314
# Epoch 23/50
# 12/12 - 0s - loss: 0.3279 - val_loss: 0.3117
# Epoch 24/50
# 12/12 - 0s - loss: 0.3055 - val_loss: 0.2999
# Epoch 25/50
# 12/12 - 0s - loss: 0.2870 - val_loss: 0.2853
# Epoch 26/50
# 12/12 - 0s - loss: 0.2787 - val_loss: 0.2726
# Epoch 27/50
# 12/12 - 0s - loss: 0.2676 - val_loss: 0.2668
# Epoch 28/50
# 12/12 - 0s - loss: 0.2667 - val_loss: 0.2644
# Epoch 29/50
# 12/12 - 0s - loss: 0.2513 - val_loss: 0.2539
# Epoch 30/50
# 12/12 - 0s - loss: 0.2563 - val_loss: 0.2493
# Epoch 31/50
# 12/12 - 0s - loss: 0.2450 - val_loss: 0.2458
# Epoch 32/50
# 12/12 - 0s - loss: 0.2283 - val_loss: 0.2416
# Epoch 33/50
# 12/12 - 0s - loss: 0.2278 - val_loss: 0.2354
# Epoch 34/50
# 12/12 - 0s - loss: 0.2248 - val_loss: 0.2359
# Epoch 35/50
# 12/12 - 0s - loss: 0.2296 - val_loss: 0.2367
# Epoch 36/50
# 12/12 - 0s - loss: 0.2287 - val_loss: 0.2353
# Epoch 37/50
# 12/12 - 0s - loss: 0.2275 - val_loss: 0.2333
# Epoch 38/50
# 12/12 - 0s - loss: 0.2269 - val_loss: 0.2322
# Epoch 39/50
# 12/12 - 0s - loss: 0.2149 - val_loss: 0.2331
# Epoch 40/50
# 12/12 - 0s - loss: 0.2183 - val_loss: 0.2288
# Epoch 41/50
# 12/12 - 0s - loss: 0.2113 - val_loss: 0.2260
# Epoch 42/50
# 12/12 - 0s - loss: 0.2157 - val_loss: 0.2259
# Epoch 43/50
# 12/12 - 0s - loss: 0.2133 - val_loss: 0.2254
# Epoch 44/50
# 12/12 - 0s - loss: 0.2140 - val_loss: 0.2257
# Epoch 45/50
# 12/12 - 0s - loss: 0.2060 - val_loss: 0.2239
# Epoch 46/50
# 12/12 - 0s - loss: 0.2000 - val_loss: 0.2245
# Epoch 47/50
# 12/12 - 0s - loss: 0.2014 - val_loss: 0.2237
# Epoch 48/50
# 12/12 - 0s - loss: 0.2021 - val_loss: 0.2210
# Epoch 49/50
# 12/12 - 0s - loss: 0.1981 - val_loss: 0.2202
# Epoch 50/50
# 12/12 - 0s - loss: 0.2065 - val_loss: 0.2215
# Epoch 1/50
# 12/12 - 1s - loss: 0.1921 - val_loss: 0.2198
# Epoch 2/50
# 12/12 - 0s - loss: 0.2019 - val_loss: 0.2198
# Epoch 3/50
# 12/12 - 0s - loss: 0.1961 - val_loss: 0.2201
# Epoch 4/50
# 12/12 - 0s - loss: 0.1963 - val_loss: 0.2198
# Epoch 5/50
# 12/12 - 0s - loss: 0.1946 - val_loss: 0.2192
# Epoch 6/50
# 12/12 - 0s - loss: 0.1974 - val_loss: 0.2188
# Epoch 7/50
# 12/12 - 0s - loss: 0.1989 - val_loss: 0.2187
# Epoch 8/50
# 12/12 - 0s - loss: 0.1969 - val_loss: 0.2183
# Epoch 9/50
# 12/12 - 0s - loss: 0.1977 - val_loss: 0.2184
# Epoch 10/50
# 12/12 - 0s - loss: 0.1969 - val_loss: 0.2185
# Epoch 11/50
# 12/12 - 0s - loss: 0.1958 - val_loss: 0.2179
# Epoch 12/50
# 12/12 - 0s - loss: 0.1968 - val_loss: 0.2177
# Epoch 13/50
# 12/12 - 0s - loss: 0.1951 - val_loss: 0.2178
# Epoch 14/50
# 12/12 - 0s - loss: 0.1891 - val_loss: 0.2182
# Epoch 15/50
# 12/12 - 0s - loss: 0.1930 - val_loss: 0.2184
# Epoch 16/50
# 12/12 - 0s - loss: 0.1925 - val_loss: 0.2174
# Epoch 17/50
# 12/12 - 0s - loss: 0.1935 - val_loss: 0.2176
# Epoch 18/50
# 12/12 - 0s - loss: 0.1967 - val_loss: 0.2175
# Epoch 19/50
# 12/12 - 0s - loss: 0.1966 - val_loss: 0.2172
# Epoch 20/50
# 12/12 - 0s - loss: 0.1917 - val_loss: 0.2171
# Epoch 21/50
# 12/12 - 0s - loss: 0.1983 - val_loss: 0.2169
# Epoch 22/50
# 12/12 - 0s - loss: 0.2015 - val_loss: 0.2168
# Epoch 23/50
# 12/12 - 0s - loss: 0.1994 - val_loss: 0.2165
# Epoch 24/50
# 12/12 - 0s - loss: 0.1934 - val_loss: 0.2165
# Epoch 25/50
# 12/12 - 0s - loss: 0.1907 - val_loss: 0.2163
# Epoch 26/50
# 12/12 - 0s - loss: 0.2002 - val_loss: 0.2161
# Epoch 27/50
# 12/12 - 0s - loss: 0.1950 - val_loss: 0.2158
# Epoch 28/50
# 12/12 - 0s - loss: 0.1886 - val_loss: 0.2164
# Epoch 29/50
# 12/12 - 0s - loss: 0.1918 - val_loss: 0.2158
# Epoch 30/50
# 12/12 - 0s - loss: 0.1894 - val_loss: 0.2161
# Epoch 31/50
# 12/12 - 0s - loss: 0.1935 - val_loss: 0.2158
# Epoch 32/50
# 12/12 - 0s - loss: 0.1910 - val_loss: 0.2155
# Epoch 33/50
# 12/12 - 0s - loss: 0.1914 - val_loss: 0.2152
# Epoch 34/50
# 12/12 - 0s - loss: 0.1882 - val_loss: 0.2154
# Epoch 35/50
# 12/12 - 0s - loss: 0.1897 - val_loss: 0.2152
# Epoch 36/50
# 12/12 - 0s - loss: 0.1903 - val_loss: 0.2148
# Epoch 37/50
# 12/12 - 0s - loss: 0.1892 - val_loss: 0.2144
# Epoch 38/50
# 12/12 - 0s - loss: 0.1899 - val_loss: 0.2149
# Epoch 39/50
# 12/12 - 0s - loss: 0.1923 - val_loss: 0.2148
# Epoch 40/50
# 12/12 - 0s - loss: 0.1986 - val_loss: 0.2155
# Epoch 41/50
# 12/12 - 0s - loss: 0.1891 - val_loss: 0.2152
# Epoch 42/50
# 12/12 - 0s - loss: 0.1955 - val_loss: 0.2147
# Epoch 43/50
# 12/12 - 0s - loss: 0.1951 - val_loss: 0.2147
# Epoch 44/50
# 12/12 - 0s - loss: 0.1971 - val_loss: 0.2143
# Epoch 45/50
# 12/12 - 0s - loss: 0.1874 - val_loss: 0.2143
# Epoch 46/50
# 12/12 - 0s - loss: 0.1906 - val_loss: 0.2139
# Epoch 47/50
# 12/12 - 0s - loss: 0.1915 - val_loss: 0.2148
# Epoch 48/50
# 12/12 - 0s - loss: 0.1905 - val_loss: 0.2143
# Epoch 49/50
# 12/12 - 0s - loss: 0.1842 - val_loss: 0.2133
# Epoch 50/50
# 12/12 - 0s - loss: 0.1865 - val_loss: 0.2135
# 24/24 - 0s - loss: 0.2133
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 90, 1)]           0
# _________________________________________________________________
# bidirectional_20 (Bidirectio (None, 90, 64)            6720
# _________________________________________________________________
# bidirectional_21 (Bidirectio (None, 64)                18816
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                1040
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 16)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 26,593
# Trainable params: 26,593
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 12/12 - 2s - loss: 2.3149 - val_loss: 1.6323
# Epoch 2/50
# 12/12 - 0s - loss: 1.8864 - val_loss: 1.5292
# Epoch 3/50
# 12/12 - 0s - loss: 1.6922 - val_loss: 1.4221
# Epoch 4/50
# 12/12 - 0s - loss: 1.5612 - val_loss: 1.3331
# Epoch 5/50
# 12/12 - 0s - loss: 1.4260 - val_loss: 1.2490
# Epoch 6/50
# 12/12 - 0s - loss: 1.3128 - val_loss: 1.1640
# Epoch 7/50
# 12/12 - 0s - loss: 1.2047 - val_loss: 1.0797
# Epoch 8/50
# 12/12 - 0s - loss: 1.1153 - val_loss: 0.9997
# Epoch 9/50
# 12/12 - 0s - loss: 1.0338 - val_loss: 0.9217
# Epoch 10/50
# 12/12 - 0s - loss: 0.9583 - val_loss: 0.8498
# Epoch 11/50
# 12/12 - 0s - loss: 0.8751 - val_loss: 0.7765
# Epoch 12/50
# 12/12 - 0s - loss: 0.7970 - val_loss: 0.7084
# Epoch 13/50
# 12/12 - 0s - loss: 0.7328 - val_loss: 0.6456
# Epoch 14/50
# 12/12 - 0s - loss: 0.6722 - val_loss: 0.5858
# Epoch 15/50
# 12/12 - 0s - loss: 0.6130 - val_loss: 0.5306
# Epoch 16/50
# 12/12 - 0s - loss: 0.5557 - val_loss: 0.4806
# Epoch 17/50
# 12/12 - 0s - loss: 0.5099 - val_loss: 0.4332
# Epoch 18/50
# 12/12 - 0s - loss: 0.4600 - val_loss: 0.3906
# Epoch 19/50
# 12/12 - 0s - loss: 0.4225 - val_loss: 0.3533
# Epoch 20/50
# 12/12 - 0s - loss: 0.3791 - val_loss: 0.3185
# Epoch 21/50
# 12/12 - 0s - loss: 0.3454 - val_loss: 0.2869
# Epoch 22/50
# 12/12 - 0s - loss: 0.3145 - val_loss: 0.2595
# Epoch 23/50
# 12/12 - 0s - loss: 0.2954 - val_loss: 0.2373
# Epoch 24/50
# 12/12 - 0s - loss: 0.2707 - val_loss: 0.2185
# Epoch 25/50
# 12/12 - 0s - loss: 0.2524 - val_loss: 0.2035
# Epoch 26/50
# 12/12 - 0s - loss: 0.2473 - val_loss: 0.1934
# Epoch 27/50
# 12/12 - 0s - loss: 0.2344 - val_loss: 0.1854
# Epoch 28/50
# 12/12 - 0s - loss: 0.2229 - val_loss: 0.1781
# Epoch 29/50
# 12/12 - 0s - loss: 0.2170 - val_loss: 0.1735
# Epoch 30/50
# 12/12 - 0s - loss: 0.2121 - val_loss: 0.1685
# Epoch 31/50
# 12/12 - 0s - loss: 0.2081 - val_loss: 0.1639
# Epoch 32/50
# 12/12 - 0s - loss: 0.2046 - val_loss: 0.1609
# Epoch 33/50
# 12/12 - 0s - loss: 0.1986 - val_loss: 0.1583
# Epoch 34/50
# 12/12 - 0s - loss: 0.1950 - val_loss: 0.1563
# Epoch 35/50
# 12/12 - 0s - loss: 0.2004 - val_loss: 0.1550
# Epoch 36/50
# 12/12 - 0s - loss: 0.1891 - val_loss: 0.1540
# Epoch 37/50
# 12/12 - 0s - loss: 0.1924 - val_loss: 0.1521
# Epoch 38/50
# 12/12 - 0s - loss: 0.1866 - val_loss: 0.1511
# Epoch 39/50
# 12/12 - 0s - loss: 0.1829 - val_loss: 0.1501
# Epoch 40/50
# 12/12 - 0s - loss: 0.1830 - val_loss: 0.1483
# Epoch 41/50
# 12/12 - 0s - loss: 0.1888 - val_loss: 0.1477
# Epoch 42/50
# 12/12 - 0s - loss: 0.1793 - val_loss: 0.1481
# Epoch 43/50
# 12/12 - 0s - loss: 0.1854 - val_loss: 0.1472
# Epoch 44/50
# 12/12 - 0s - loss: 0.1780 - val_loss: 0.1467
# Epoch 45/50
# 12/12 - 0s - loss: 0.1892 - val_loss: 0.1468
# Epoch 46/50
# 12/12 - 0s - loss: 0.1751 - val_loss: 0.1445
# Epoch 47/50
# 12/12 - 0s - loss: 0.1799 - val_loss: 0.1447
# Epoch 48/50
# 12/12 - 0s - loss: 0.1744 - val_loss: 0.1432
# Epoch 49/50
# 12/12 - 0s - loss: 0.1717 - val_loss: 0.1434
# Epoch 50/50
# 12/12 - 0s - loss: 0.1669 - val_loss: 0.1429
# Epoch 1/50
# 12/12 - 1s - loss: 0.1706 - val_loss: 0.1417
# Epoch 2/50
# 12/12 - 0s - loss: 0.1700 - val_loss: 0.1408
# Epoch 3/50
# 12/12 - 0s - loss: 0.1726 - val_loss: 0.1406
# Epoch 4/50
# 12/12 - 0s - loss: 0.1679 - val_loss: 0.1404
# Epoch 5/50
# 12/12 - 0s - loss: 0.1661 - val_loss: 0.1406
# Epoch 6/50
# 12/12 - 0s - loss: 0.1686 - val_loss: 0.1402
# Epoch 7/50
# 12/12 - 0s - loss: 0.1692 - val_loss: 0.1401
# Epoch 8/50
# 12/12 - 0s - loss: 0.1727 - val_loss: 0.1402
# Epoch 9/50
# 12/12 - 0s - loss: 0.1659 - val_loss: 0.1402
# Epoch 10/50
# 12/12 - 0s - loss: 0.1687 - val_loss: 0.1400
# Epoch 11/50
# 12/12 - 0s - loss: 0.1745 - val_loss: 0.1404
# Epoch 12/50
# 12/12 - 0s - loss: 0.1706 - val_loss: 0.1402
# Epoch 13/50
# 12/12 - 0s - loss: 0.1697 - val_loss: 0.1400
# Epoch 14/50
# 12/12 - 0s - loss: 0.1686 - val_loss: 0.1399
# Epoch 15/50
# 12/12 - 0s - loss: 0.1658 - val_loss: 0.1399
# Epoch 16/50
# 12/12 - 0s - loss: 0.1699 - val_loss: 0.1397
# Epoch 17/50
# 12/12 - 0s - loss: 0.1703 - val_loss: 0.1394
# Epoch 18/50
# 12/12 - 0s - loss: 0.1700 - val_loss: 0.1396
# Epoch 19/50
# 12/12 - 0s - loss: 0.1691 - val_loss: 0.1398
# Epoch 20/50
# 12/12 - 0s - loss: 0.1686 - val_loss: 0.1396
# Epoch 21/50
# 12/12 - 0s - loss: 0.1660 - val_loss: 0.1396
# Epoch 22/50
# 12/12 - 0s - loss: 0.1647 - val_loss: 0.1395
# Epoch 23/50
# 12/12 - 0s - loss: 0.1666 - val_loss: 0.1395
# Epoch 24/50
# 12/12 - 0s - loss: 0.1613 - val_loss: 0.1392
# Epoch 25/50
# 12/12 - 0s - loss: 0.1672 - val_loss: 0.1392
# Epoch 26/50
# 12/12 - 0s - loss: 0.1686 - val_loss: 0.1393
# Epoch 27/50
# 12/12 - 0s - loss: 0.1649 - val_loss: 0.1391
# Epoch 28/50
# 12/12 - 0s - loss: 0.1661 - val_loss: 0.1391
# Epoch 29/50
# 12/12 - 0s - loss: 0.1595 - val_loss: 0.1390
# Epoch 30/50
# 12/12 - 0s - loss: 0.1663 - val_loss: 0.1388
# Epoch 31/50
# 12/12 - 0s - loss: 0.1603 - val_loss: 0.1385
# Epoch 32/50
# 12/12 - 0s - loss: 0.1642 - val_loss: 0.1385
# Epoch 33/50
# 12/12 - 0s - loss: 0.1661 - val_loss: 0.1388
# Epoch 34/50
# 12/12 - 0s - loss: 0.1634 - val_loss: 0.1387
# Epoch 35/50
# 12/12 - 0s - loss: 0.1659 - val_loss: 0.1384
# Epoch 36/50
# 12/12 - 0s - loss: 0.1668 - val_loss: 0.1382
# Epoch 37/50
# 12/12 - 0s - loss: 0.1627 - val_loss: 0.1381
# Epoch 38/50
# 12/12 - 0s - loss: 0.1664 - val_loss: 0.1379
# Epoch 39/50
# 12/12 - 0s - loss: 0.1665 - val_loss: 0.1381
# Epoch 40/50
# 12/12 - 0s - loss: 0.1585 - val_loss: 0.1383
# Epoch 41/50
# 12/12 - 0s - loss: 0.1630 - val_loss: 0.1381
# Epoch 42/50
# 12/12 - 0s - loss: 0.1708 - val_loss: 0.1382
# Epoch 43/50
# 12/12 - 0s - loss: 0.1599 - val_loss: 0.1382
# Epoch 44/50
# 12/12 - 0s - loss: 0.1597 - val_loss: 0.1379
# Epoch 45/50
# 12/12 - 0s - loss: 0.1634 - val_loss: 0.1374
# Epoch 46/50
# 12/12 - 0s - loss: 0.1610 - val_loss: 0.1374
# Epoch 47/50
# 12/12 - 0s - loss: 0.1592 - val_loss: 0.1373
# Epoch 48/50
# 12/12 - 0s - loss: 0.1668 - val_loss: 0.1372
# Epoch 49/50
# 12/12 - 0s - loss: 0.1615 - val_loss: 0.1369
# Epoch 50/50
# 12/12 - 0s - loss: 0.1665 - val_loss: 0.1372
# 24/24 - 0s - loss: 0.1369

# %% [markdown]
# <h3>3.3 單次預測</h3>
#
#     以90天資料，預測下一天的數值。

# %%
Predict = 0
for i in range(11):
    Predict += d[f'Predict{i}']
d[f'Predict'] = Predict
plt.figure(figsize=(16, 4))
plt.plot(d['Actual'][-Predict.shape[0]:], label='Actual')
plt.plot(Predict, label='Predict')
plt.title('Predict')
plt.legend()
plt.show()

# %% [markdown]
# <h3>3.4 連續預測</h3>
#
#     以90天資料，預測下一天數值，並將結果作為輸入再進行預測。

# %%
def Forecast(data, model):
    a = data.shape[0]
    b = []
    for _ in range(length):
        predict = list(model.predict(data[-a:, 0].reshape(1, -1, 1)).reshape(-1))
        b.append(predict)
        data = np.array(list(data.reshape(-1)) + predict).reshape(-1, 1)
    return np.array(b)

# %%
forecast = 0
start = 0
length = 60
plt.figure(figsize=(16, 22))
for mode in range(11):
    filepath = f'{mode}.h5'
    model = load_model(filepath)
    result = Forecast(d[f'x_test{mode}'][start], model) * d[f'std{mode}'] + d[f'mean{mode}']
    plt.subplot(11, 1, mode+1)
    plt.plot(d[f'Actual{mode}'][start:start+60])
    plt.plot(result)
    plt.title(f'Mode {mode}')
    forecast += result
plt.show()
plt.figure(figsize=(16, 4))
plt.plot(d[f'Actual'][-750:])
plt.plot(range(start, start+length),forecast)
plt.title('Forecast')
plt.show()

# %% [markdown]
# <h3>4. 總結</h3>

# %%
result = pd.DataFrame(columns=['Actual'], data=d['Actual'][-750:])
result['Predict'] = d['Predict']
for i in range(11):
    result[f'Actual{i}'] = d[f'Actual{i}']
    result[f'Predict{i}'] = d[f'Predict{i}']

# %%
evaluate = pd.DataFrame(columns=['Total'], data=[(round(np.mean(abs(d[f'Actual'][-750:]-d[f'Predict'].reshape(-1))), 2))])
for i in range(11):
    evaluate[f'Mode{i}'] = [round(np.mean(abs(d[f'Actual{i}']-d[f'Predict{i}'])), 2)]

# %%
result.to_csv('BDI_EEMD-LSTM.csv', index=False, header=True)
result
# Out:
#      Actual      Predict    Actual0   Predict0    Actual1   Predict1  \
# 0    1413.0  1352.239746  29.671862  -3.300498  14.590753  16.527119
# 1    1413.0  1347.334106 -10.506141 -12.121601   3.680280  10.479972
# 2    1413.0  1380.557739 -33.373606  -3.558621  12.644650   5.802976
# 3    1434.0  1392.489502  36.746924   6.981378  -6.791137   9.633073
# 4    1450.0  1391.977295   9.712564  -3.675640   8.665448  -4.870699
# ..      ...          ...        ...        ...        ...        ...
# 745  2071.0  1998.745239  40.450728   3.645043 -11.320099  23.218008
# 746  2097.0  1995.656738  33.714569 -12.372774  -0.853521  -7.772633
# 747  2044.0  2037.644531   6.797522  -1.615569 -18.806117  -4.685214
# 748  1970.0  2030.083374 -52.018953 -15.723370 -78.123231 -15.167903
# 749  1892.0  2006.002441 -35.422170  11.406124 -52.419424 -51.209709
#
#        Actual2    Predict2     Actual3    Predict3  ...     Actual6  \
# 0    13.865327    7.499531  -18.413368  -32.896660  ...  164.690042
# 1    31.899884   14.253846    3.460089  -22.525963  ...  155.133810
# 2    24.375744   28.080114    7.791265    2.543101  ...  154.175909
# 3    26.188261   24.456108   22.953289    6.099246  ...  146.947896
# 4    36.560972   26.474321   19.746623   23.271526  ...  152.480164
# ..         ...         ...         ...         ...  ...         ...
# 745  89.716405  100.293129  240.062490  239.535736  ...  257.510721
# 746  77.884249   78.025810  245.349359  239.290482  ...  257.022663
# 747  48.738259   68.880753  232.402168  243.191360  ...  266.628336
# 748  -8.819667   49.093536  230.399109  230.064926  ...  267.852471
# 749 -50.143955   -5.655832  174.630894  227.427124  ...  275.432599
#
#        Predict6     Actual7    Predict7     Actual8    Predict8     Actual9  \
# 0    151.127136  147.337737  138.387054  411.567873  365.714294 -433.526395
# 1    163.721710  121.083717  147.673630  424.513943  384.525421 -453.291641
# 2    154.024231  149.878471  120.479469  385.249024  395.940491 -399.028643
# 3    153.016907  151.941743  150.297638  368.146874  361.626099 -350.761145
# 4    145.619873  143.573623  152.416473  380.139764  345.678314 -353.321658
# ..          ...         ...         ...         ...         ...         ...
# 745  243.496124  118.058298  105.860023  162.660179  194.687683  -58.919180
# 746  256.952606  113.387954  116.091583  184.910112  159.628143  -74.567894
# 747  256.527374  108.806570  111.274956  162.904045  179.997162  -33.118218
# 748  266.569183  106.821550  106.641441  175.510679  159.860260  -60.232913
# 749  267.824066   97.618723  104.569763  219.911729  171.405121 -126.912173
#
#        Predict9     Actual10    Predict10
# 0   -370.933533  1298.008671  1264.495728
# 1   -415.142090  1321.996656  1289.712402
# 2   -431.928101  1287.827300  1312.783569
# 3   -385.929138  1257.091206  1280.073242
# 4   -344.507812  1250.574675  1250.713745
# ..          ...          ...          ...
# 745  -98.511322  1079.629981  1076.248413
# 746  -73.942947  1086.199341  1081.068115
# 747  -89.363586  1068.343772  1087.135986
# 748  -47.207153  1086.554401  1070.401855
# 749  -75.055939  1117.415340  1087.490356
#
# [750 rows x 24 columns]

# %%
evaluate.to_csv('Evaluate.csv', index=False, header=True)
evaluate
# Out:
#    Total  Mode0  Mode1  Mode2  Mode3  Mode4  Mode5  Mode6  Mode7  Mode8  \
# 0  50.98  20.42  15.02  13.04  12.47  11.35  16.15  14.37   9.06  23.56
#
#    Mode9  Mode10
# 0  33.53   16.09

# %%
np.save('BDI_EEMD-LSTM.npy', d)

# %%
d = np.load('BDI_EEMD-LSTM.npy',allow_pickle='TRUE').item()
d.keys()
# Out:
# dict_keys(['Actual', 'mean10', 'std10', 'x_test10', 'Predict10', 'Actual10', 'mean4', 'std4', 'x_test4', 'Predict4', 'Actual4', 'mean5', 'std5', 'x_test5', 'Predict5', 'Actual5', 'mean6', 'std6', 'x_test6', 'Predict6', 'Actual6', 'mean7', 'std7', 'x_test7', 'Predict7', 'Actual7', 'mean8', 'std8', 'x_test8', 'Predict8', 'Actual8', 'mean9', 'std9', 'x_test9', 'Predict9', 'Actual9', 'mean0', 'std0', 'x_test0', 'Predict0', 'Actual0', 'mean1', 'std1', 'x_test1', 'Predict1', 'Actual1', 'mean2', 'std2', 'x_test2', 'Predict2', 'Actual2', 'mean3', 'std3', 'x_test3', 'Predict3', 'Actual3', 'Predict'])
